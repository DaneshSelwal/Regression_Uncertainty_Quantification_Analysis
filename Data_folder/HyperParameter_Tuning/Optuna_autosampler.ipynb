# %% [markdown]
# # **Start**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Uninstall existing scikit-learn to avoid conflicts
# !pip uninstall -y scikit-learn
# Install specific versions of libraries to avoid conflicts
# !pip install scikit-learn==1.5.2
# !pip install bayesian-optimization==3.2.0
# !pip install optuna==4.6.0
# !pip install gpboost==1.6.1
# !pip install shap==0.50.0
# !pip install ngboost==0.5.8
# !pip install dask[dataframe]==2025.12.0
# !pip install torch==2.9.0+cpu
# !pip install seaborn==0.13.2
# !pip install lightgbm==4.6.0
# !pip install xgboost==3.1.2
# !pip install lime==0.2.0.1
# !pip install interpret==0.7.4
# !pip install optunahub==0.4.0
# !pip install cmaes==0.12.0
# !pip install plotly==5.24.1
# !pip install kaleido==1.2.0
# !pip install openpyxl==3.1.5
# !pip install properscoring==0.1
# !pip install XlsxWriter==3.2.9
# !pip install cython==3.0.12
# !pip install pgbm==2.2.0
# !pip install cp==2020.12.3
# !pip install mapie==0.6.0
# !pip install skorch==1.3.1
# !pip install puncc==0.8.0
# Reinstall scikit-learn to the version required by ngboost
# !pip uninstall -y scikit-learn
# !pip install scikit-learn==1.6.1
# Reinstall numpy first
# !pip install numpy==1.26.4  # Use the version compatible with catboost
# Reinstall catboost
# !pip install catboost==1.2.8
# !pip install pytorch-tabnet2==4.5.3
# Out:
# Found existing installation: scikit-learn 1.6.1
# Uninstalling scikit-learn-1.6.1:
#   Successfully uninstalled scikit-learn-1.6.1
# Collecting scikit-learn==1.5.2
#   Downloading scikit_learn-1.5.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.5.2) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.5.2) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.5.2) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.5.2) (3.6.0)
# Downloading scikit_learn-1.5.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 101.3 MB/s eta 0:00:00
# Installing collected packages: scikit-learn
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.5.2 which is incompatible.
# hdbscan 0.8.41 requires scikit-learn>=1.6, but you have scikit-learn 1.5.2 which is incompatible.
# Successfully installed scikit-learn-1.5.2
# Collecting bayesian-optimization==3.2.0
#   Downloading bayesian_optimization-3.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting colorama>=0.4.6 (from bayesian-optimization==3.2.0)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.12/dist-packages (from bayesian-optimization==3.2.0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from bayesian-optimization==3.2.0) (25.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from bayesian-optimization==3.2.0) (1.5.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from bayesian-optimization==3.2.0) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->bayesian-optimization==3.2.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->bayesian-optimization==3.2.0) (3.6.0)
# Downloading bayesian_optimization-3.2.0-py3-none-any.whl (37 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama, bayesian-optimization
# Successfully installed bayesian-optimization-3.2.0 colorama-0.4.6
# Collecting optuna==4.6.0
#   Downloading optuna-4.6.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna==4.6.0) (1.17.2)
# Collecting colorlog (from optuna==4.6.0)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna==4.6.0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna==4.6.0) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna==4.6.0) (2.0.45)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna==4.6.0) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna==4.6.0) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna==4.6.0) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna==4.6.0) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna==4.6.0) (3.3.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna==4.6.0) (3.0.3)
# Downloading optuna-4.6.0-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 7.0 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.6.0
# Collecting gpboost==1.6.1
#   Downloading gpboost-1.6.1-py3-none-manylinux1_x86_64.whl.metadata (7.9 kB)
# Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (from gpboost==1.6.1) (0.45.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from gpboost==1.6.1) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from gpboost==1.6.1) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from gpboost==1.6.1) (1.16.3)
# Requirement already satisfied: scikit-learn!=0.22.0 in /usr/local/lib/python3.12/dist-packages (from gpboost==1.6.1) (1.5.2)
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (from gpboost==1.6.1) (4.6.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn!=0.22.0->gpboost==1.6.1) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn!=0.22.0->gpboost==1.6.1) (3.6.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna->gpboost==1.6.1) (1.17.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna->gpboost==1.6.1) (6.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna->gpboost==1.6.1) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna->gpboost==1.6.1) (2.0.45)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna->gpboost==1.6.1) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna->gpboost==1.6.1) (6.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->gpboost==1.6.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->gpboost==1.6.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->gpboost==1.6.1) (2025.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna->gpboost==1.6.1) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna->gpboost==1.6.1) (4.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->gpboost==1.6.1) (1.17.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna->gpboost==1.6.1) (3.3.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna->gpboost==1.6.1) (3.0.3)
# Downloading gpboost-1.6.1-py3-none-manylinux1_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 25.5 MB/s eta 0:00:00
# Installing collected packages: gpboost
# Successfully installed gpboost-1.6.1
# Requirement already satisfied: shap==0.50.0 in /usr/local/lib/python3.12/dist-packages (0.50.0)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from shap==0.50.0) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from shap==0.50.0) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from shap==0.50.0) (1.5.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from shap==0.50.0) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.12/dist-packages (from shap==0.50.0) (4.67.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.12/dist-packages (from shap==0.50.0) (25.0)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from shap==0.50.0) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.12/dist-packages (from shap==0.50.0) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from shap==0.50.0) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from shap==0.50.0) (4.15.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.54->shap==0.50.0) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->shap==0.50.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->shap==0.50.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->shap==0.50.0) (2025.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->shap==0.50.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->shap==0.50.0) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->shap==0.50.0) (1.17.0)
# Collecting ngboost==0.5.8
#   Downloading ngboost-0.5.8-py3-none-any.whl.metadata (4.2 kB)
# Collecting lifelines>=0.25 (from ngboost==0.5.8)
#   Downloading lifelines-0.30.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.12/dist-packages (from ngboost==0.5.8) (2.0.2)
# Collecting scikit-learn<2.0,>=1.6 (from ngboost==0.5.8)
#   Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: scipy>=1.7.2 in /usr/local/lib/python3.12/dist-packages (from ngboost==0.5.8) (1.16.3)
# Requirement already satisfied: tqdm>=4.3 in /usr/local/lib/python3.12/dist-packages (from ngboost==0.5.8) (4.67.1)
# Requirement already satisfied: pandas>=2.1 in /usr/local/lib/python3.12/dist-packages (from lifelines>=0.25->ngboost==0.5.8) (2.2.2)
# Requirement already satisfied: matplotlib>=3.0 in /usr/local/lib/python3.12/dist-packages (from lifelines>=0.25->ngboost==0.5.8) (3.10.0)
# Requirement already satisfied: autograd>=1.5 in /usr/local/lib/python3.12/dist-packages (from lifelines>=0.25->ngboost==0.5.8) (1.8.0)
# Collecting autograd-gamma>=0.3 (from lifelines>=0.25->ngboost==0.5.8)
#   Downloading autograd-gamma-0.5.0.tar.gz (4.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting formulaic>=0.2.2 (from lifelines>=0.25->ngboost==0.5.8)
#   Downloading formulaic-1.2.1-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: joblib>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2.0,>=1.6->ngboost==0.5.8) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2.0,>=1.6->ngboost==0.5.8) (3.6.0)
# Collecting interface-meta>=1.2.0 (from formulaic>=0.2.2->lifelines>=0.25->ngboost==0.5.8)
#   Downloading interface_meta-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: narwhals>=1.17 in /usr/local/lib/python3.12/dist-packages (from formulaic>=0.2.2->lifelines>=0.25->ngboost==0.5.8) (2.15.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from formulaic>=0.2.2->lifelines>=0.25->ngboost==0.5.8) (4.15.0)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.12/dist-packages (from formulaic>=0.2.2->lifelines>=0.25->ngboost==0.5.8) (2.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost==0.5.8) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost==0.5.8) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost==0.5.8) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost==0.5.8) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost==0.5.8) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost==0.5.8) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost==0.5.8) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost==0.5.8) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->lifelines>=0.25->ngboost==0.5.8) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->lifelines>=0.25->ngboost==0.5.8) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0->lifelines>=0.25->ngboost==0.5.8) (1.17.0)
# Downloading ngboost-0.5.8-py3-none-any.whl (36 kB)
# Downloading lifelines-0.30.0-py3-none-any.whl (349 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.3/349.3 kB 10.6 MB/s eta 0:00:00
# Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 70.5 MB/s eta 0:00:00
# Downloading formulaic-1.2.1-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.3/117.3 kB 8.5 MB/s eta 0:00:00
# Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Building wheels for collected packages: autograd-gamma
#   Building wheel for autograd-gamma (setup.py) ... done
#   Created wheel for autograd-gamma: filename=autograd_gamma-0.5.0-py3-none-any.whl size=4030 sha256=61a3c212758ac7f818d5c52593bb06bad2c3cecba38d7796c4d930c7f6f34838
#   Stored in directory: /root/.cache/pip/wheels/50/37/21/0a719b9d89c635e89ff24bd93b862882ad675279552013b2fb
# Successfully built autograd-gamma
# Installing collected packages: interface-meta, scikit-learn, autograd-gamma, formulaic, lifelines, ngboost
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.5.2
#     Uninstalling scikit-learn-1.5.2:
#       Successfully uninstalled scikit-learn-1.5.2
# Successfully installed autograd-gamma-0.5.0 formulaic-1.2.1 interface-meta-1.3.0 lifelines-0.30.0 ngboost-0.5.8 scikit-learn-1.8.0
# Requirement already satisfied: dask==2025.12.0 in /usr/local/lib/python3.12/dist-packages (from dask[dataframe]==2025.12.0) (2025.12.0)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.12/dist-packages (from dask==2025.12.0->dask[dataframe]==2025.12.0) (8.3.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dask==2025.12.0->dask[dataframe]==2025.12.0) (3.1.2)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.12/dist-packages (from dask==2025.12.0->dask[dataframe]==2025.12.0) (2025.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from dask==2025.12.0->dask[dataframe]==2025.12.0) (25.0)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from dask==2025.12.0->dask[dataframe]==2025.12.0) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from dask==2025.12.0->dask[dataframe]==2025.12.0) (6.0.3)
# Requirement already satisfied: toolz>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from dask==2025.12.0->dask[dataframe]==2025.12.0) (0.12.1)
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.12/dist-packages (from dask[dataframe]==2025.12.0) (2.2.2)
# Requirement already satisfied: pyarrow>=14.0.1 in /usr/local/lib/python3.12/dist-packages (from dask[dataframe]==2025.12.0) (18.1.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->dask[dataframe]==2025.12.0) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->dask[dataframe]==2025.12.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->dask[dataframe]==2025.12.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->dask[dataframe]==2025.12.0) (2025.3)
# Requirement already satisfied: locket in /usr/local/lib/python3.12/dist-packages (from partd>=1.4.0->dask==2025.12.0->dask[dataframe]==2025.12.0) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0->dask[dataframe]==2025.12.0) (1.17.0)
# Requirement already satisfied: torch==2.9.0+cpu in /usr/local/lib/python3.12/dist-packages (2.9.0+cpu)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0+cpu) (3.20.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0+cpu) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0+cpu) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0+cpu) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0+cpu) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0+cpu) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0+cpu) (2025.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.9.0+cpu) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.9.0+cpu) (3.0.3)
# Requirement already satisfied: seaborn==0.13.2 in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.12/dist-packages (from seaborn==0.13.2) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.12/dist-packages (from seaborn==0.13.2) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.12/dist-packages (from seaborn==0.13.2) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn==0.13.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn==0.13.2) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.17.0)
# Requirement already satisfied: lightgbm==4.6.0 in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from lightgbm==4.6.0) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from lightgbm==4.6.0) (1.16.3)
# Requirement already satisfied: xgboost==3.1.2 in /usr/local/lib/python3.12/dist-packages (3.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.2) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.2) (2.29.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.2) (1.16.3)
# Collecting lime==0.2.0.1
#   Downloading lime-0.2.0.1.tar.gz (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 6.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from lime==0.2.0.1) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from lime==0.2.0.1) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from lime==0.2.0.1) (1.16.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from lime==0.2.0.1) (4.67.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.12/dist-packages (from lime==0.2.0.1) (1.8.0)
# Requirement already satisfied: scikit-image>=0.12 in /usr/local/lib/python3.12/dist-packages (from lime==0.2.0.1) (0.25.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.12->lime==0.2.0.1) (3.6.1)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.12->lime==0.2.0.1) (11.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.12->lime==0.2.0.1) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.12->lime==0.2.0.1) (2025.12.20)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.12->lime==0.2.0.1) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.12->lime==0.2.0.1) (0.4)
# Requirement already satisfied: joblib>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.18->lime==0.2.0.1) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.18->lime==0.2.0.1) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->lime==0.2.0.1) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->lime==0.2.0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->lime==0.2.0.1) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->lime==0.2.0.1) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->lime==0.2.0.1) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->lime==0.2.0.1) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->lime==0.2.0.1) (1.17.0)
# Building wheels for collected packages: lime
#   Building wheel for lime (setup.py) ... done
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283834 sha256=467b61fbcbd82d3f7404c6371b05899bdd7834b0acc4c52c61e5c74c8db11564
#   Stored in directory: /root/.cache/pip/wheels/e7/5d/0e/4b4fff9a47468fed5633211fb3b76d1db43fe806a17fb7486a
# Successfully built lime
# Installing collected packages: lime
# Successfully installed lime-0.2.0.1
# Collecting interpret==0.7.4
#   Downloading interpret-0.7.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting interpret-core==0.7.4 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4)
#   Downloading interpret_core-0.7.4-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.12/dist-packages (from interpret-core==0.7.4->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (2.0.2)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.12/dist-packages (from interpret-core==0.7.4->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from interpret-core==0.7.4->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (1.8.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.12/dist-packages (from interpret-core==0.7.4->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (1.5.3)
# Requirement already satisfied: psutil>=5.6.2 in /usr/local/lib/python3.12/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (5.9.5)
# Requirement already satisfied: ipykernel>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (6.17.1)
# Requirement already satisfied: ipython>=5.5.0 in /usr/local/lib/python3.12/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (7.34.0)
# Requirement already satisfied: plotly>=3.8.1 in /usr/local/lib/python3.12/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (5.24.1)
# Collecting SALib>=1.3.3 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4)
#   Downloading salib-1.5.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: shap>=0.28.5 in /usr/local/lib/python3.12/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (0.50.0)
# Requirement already satisfied: dill>=0.2.5 in /usr/local/lib/python3.12/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (0.3.8)
# Collecting aplr>=10.6.1 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4)
#   Downloading aplr-10.20.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.0 kB)
# Collecting dash<3.0.0,>=2.0.0 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4)
#   Downloading dash-2.18.2-py3-none-any.whl.metadata (10 kB)
# Collecting dash-cytoscape>=0.1.1 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4)
#   Downloading dash_cytoscape-1.0.2.tar.gz (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 39.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gevent>=1.3.6 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4)
#   Downloading gevent-25.9.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (2.32.4)
# Collecting Flask<3.1,>=1.0.4 (from dash<3.0.0,>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4)
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting Werkzeug<3.1 (from dash<3.0.0,>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4)
#   Downloading werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Collecting dash-html-components==2.0.0 (from dash<3.0.0,>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash<3.0.0,>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash<3.0.0,>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4)
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.12/dist-packages (from dash<3.0.0,>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (8.7.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from dash<3.0.0,>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (4.15.0)
# Collecting retrying (from dash<3.0.0,>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4)
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from dash<3.0.0,>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from dash<3.0.0,>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (75.2.0)
# Requirement already satisfied: greenlet>=3.2.2 in /usr/local/lib/python3.12/dist-packages (from gevent>=1.3.6->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (3.3.0)
# Collecting zope.event (from gevent>=1.3.6->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4)
#   Downloading zope_event-6.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting zope.interface (from gevent>=1.3.6->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4)
#   Downloading zope_interface-8.2-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (0.2.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (25.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (6.5.1)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (5.7.1)
# Collecting jedi>=0.16 (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (4.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.19.2->interpret-core==0.7.4->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.19.2->interpret-core==0.7.4->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.19.2->interpret-core==0.7.4->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (2025.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=3.8.1->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (9.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (2026.1.4)
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.12/dist-packages (from SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (3.10.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (0.70.16)
# Requirement already satisfied: scipy>=1.9.3 in /usr/local/lib/python3.12/dist-packages (from SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (1.16.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.0->interpret-core==0.7.4->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (3.6.0)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.12/dist-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (4.67.1)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.12/dist-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (3.1.2)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from Flask<3.1,>=1.0.4->dash<3.0.0,>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.12/dist-packages (from Flask<3.1,>=1.0.4->dash<3.0.0,>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from Flask<3.1,>=1.0.4->dash<3.0.0,>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (8.3.1)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.12/dist-packages (from Flask<3.1,>=1.0.4->dash<3.0.0,>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (1.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (0.8.5)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (5.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (3.3.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.54->shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (0.43.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (0.2.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=0.19.2->interpret-core==0.7.4->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from Werkzeug<3.1->dash<3.0.0,>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (3.0.3)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata->dash<3.0.0,>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (3.23.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.4->interpret==0.7.4) (4.5.1)
# Downloading interpret-0.7.4-py3-none-any.whl (1.4 kB)
# Downloading interpret_core-0.7.4-py3-none-any.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 80.2 MB/s eta 0:00:00
# Downloading aplr-10.20.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 83.0 MB/s eta 0:00:00
# Downloading dash-2.18.2-py3-none-any.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 108.7 MB/s eta 0:00:00
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading gevent-25.9.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 68.2 MB/s eta 0:00:00
# Downloading salib-1.5.2-py3-none-any.whl (780 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.1/780.1 kB 42.3 MB/s eta 0:00:00
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 6.6 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 67.5 MB/s eta 0:00:00
# Downloading werkzeug-3.0.6-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.0/228.0 kB 13.0 MB/s eta 0:00:00
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Downloading zope_event-6.1-py3-none-any.whl (6.4 kB)
# Downloading zope_interface-8.2-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (264 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.9/264.9 kB 15.6 MB/s eta 0:00:00
# Building wheels for collected packages: dash-cytoscape
#   Building wheel for dash-cytoscape (setup.py) ... done
#   Created wheel for dash-cytoscape: filename=dash_cytoscape-1.0.2-py3-none-any.whl size=4010717 sha256=cce79688a9b7e4a16795161f66914095dbef45b0ded1e79e15db10bef3c64173
#   Stored in directory: /root/.cache/pip/wheels/0c/db/f6/9dcb225e9adf45dfef713542769556b1f508170a0759053892
# Successfully built dash-cytoscape
# Installing collected packages: dash-table, dash-html-components, dash-core-components, zope.interface, zope.event, Werkzeug, retrying, jedi, gevent, Flask, SALib, interpret-core, dash, aplr, dash-cytoscape, interpret
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 3.1.5
#     Uninstalling Werkzeug-3.1.5:
#       Successfully uninstalled Werkzeug-3.1.5
#   Attempting uninstall: Flask
#     Found existing installation: Flask 3.1.2
#     Uninstalling Flask-3.1.2:
#       Successfully uninstalled Flask-3.1.2
# Successfully installed Flask-3.0.3 SALib-1.5.2 Werkzeug-3.0.6 aplr-10.20.1 dash-2.18.2 dash-core-components-2.0.0 dash-cytoscape-1.0.2 dash-html-components-2.0.0 dash-table-5.0.0 gevent-25.9.1 interpret-0.7.4 interpret-core-0.7.4 jedi-0.19.2 retrying-1.4.2 zope.event-6.1 zope.interface-8.2
# Collecting optunahub==0.4.0
#   Downloading optunahub-0.4.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (from optunahub==0.4.0) (4.6.0)
# Requirement already satisfied: GitPython in /usr/local/lib/python3.12/dist-packages (from optunahub==0.4.0) (3.1.46)
# Collecting PyGithub>=1.59 (from optunahub==0.4.0)
#   Downloading pygithub-2.8.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting pynacl>=1.4.0 (from PyGithub>=1.59->optunahub==0.4.0)
#   Downloading pynacl-1.6.2-cp38-abi3-manylinux_2_34_x86_64.whl.metadata (10.0 kB)
# Requirement already satisfied: requests>=2.14.0 in /usr/local/lib/python3.12/dist-packages (from PyGithub>=1.59->optunahub==0.4.0) (2.32.4)
# Requirement already satisfied: pyjwt>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.4.0->PyGithub>=1.59->optunahub==0.4.0) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from PyGithub>=1.59->optunahub==0.4.0) (4.15.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from PyGithub>=1.59->optunahub==0.4.0) (2.5.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from GitPython->optunahub==0.4.0) (4.0.12)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna->optunahub==0.4.0) (1.17.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna->optunahub==0.4.0) (6.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna->optunahub==0.4.0) (2.0.2)
# ...
# Downloading xlsxwriter-3.2.9-py3-none-any.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 4.6 MB/s eta 0:00:00
# Installing collected packages: XlsxWriter
# Successfully installed XlsxWriter-3.2.9
# Requirement already satisfied: cython==3.0.12 in /usr/local/lib/python3.12/dist-packages (3.0.12)
# Collecting pgbm==2.2.0
#   Downloading pgbm-2.2.0.tar.gz (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 17.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scikit-learn>=1.1.2 in /usr/local/lib/python3.12/dist-packages (from pgbm==2.2.0) (1.8.0)
# Collecting ninja>=1.10.2.2 (from pgbm==2.2.0)
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: numba>=0.56 in /usr/local/lib/python3.12/dist-packages (from pgbm==2.2.0) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.56->pgbm==2.2.0) (0.43.0)
# Requirement already satisfied: numpy<2.1,>=1.22 in /usr/local/lib/python3.12/dist-packages (from numba>=0.56->pgbm==2.2.0) (2.0.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.2->pgbm==2.2.0) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.2->pgbm==2.2.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.2->pgbm==2.2.0) (3.6.0)
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 11.3 MB/s eta 0:00:00
# Building wheels for collected packages: pgbm
#   Building wheel for pgbm (pyproject.toml) ... done
#   Created wheel for pgbm: filename=pgbm-2.2.0-cp312-cp312-linux_x86_64.whl size=5367197 sha256=a94c81d52cc2323d2706940104ec537363dc4093bc74301b4b80f7b263a9b515
#   Stored in directory: /root/.cache/pip/wheels/29/f6/5e/cfb50c9a6356c0773742d3d55c0b7bc9813376d152c206521a
# Successfully built pgbm
# Installing collected packages: ninja, pgbm
# Successfully installed ninja-1.13.0 pgbm-2.2.0
# Collecting cp==2020.12.3
#   Downloading cp-2020.12.3.tar.gz (1.4 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: cp
#   Building wheel for cp (setup.py) ... done
#   Created wheel for cp: filename=cp-2020.12.3-py3-none-any.whl size=1420 sha256=730c8458293657b72c6b7269d17d2b5d2c08350720e754d118e97169ef46e81c
#   Stored in directory: /root/.cache/pip/wheels/ce/63/fc/1a421c2c2a8fd4cec74f2b4077b1db348c8f154556b751d2b0
# Successfully built cp
# Installing collected packages: cp
# Successfully installed cp-2020.12.3
# Collecting mapie==0.6.0
#   Downloading MAPIE-0.6.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from mapie==0.6.0) (1.8.0)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.12/dist-packages (from mapie==0.6.0) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from mapie==0.6.0) (25.0)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->mapie==0.6.0) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->mapie==0.6.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->mapie==0.6.0) (3.6.0)
# Downloading MAPIE-0.6.0-py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: mapie
# Successfully installed mapie-0.6.0
# Collecting skorch==1.3.1
#   Downloading skorch-1.3.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from skorch==1.3.1) (2.0.2)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from skorch==1.3.1) (1.8.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from skorch==1.3.1) (1.16.3)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.12/dist-packages (from skorch==1.3.1) (0.9.0)
# Requirement already satisfied: tqdm>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from skorch==1.3.1) (4.67.1)
# Requirement already satisfied: joblib>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.0->skorch==1.3.1) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.0->skorch==1.3.1) (3.6.0)
# Downloading skorch-1.3.1-py3-none-any.whl (268 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.5/268.5 kB 5.5 MB/s eta 0:00:00
# Installing collected packages: skorch
# Successfully installed skorch-1.3.1
# Collecting puncc==0.8.0
#   Downloading puncc-0.8.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from puncc==0.8.0) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from puncc==0.8.0) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from puncc==0.8.0) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from puncc==0.8.0) (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from puncc==0.8.0) (1.8.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from puncc==0.8.0) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->puncc==0.8.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->puncc==0.8.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->puncc==0.8.0) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->puncc==0.8.0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->puncc==0.8.0) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->puncc==0.8.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->puncc==0.8.0) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->puncc==0.8.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->puncc==0.8.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->puncc==0.8.0) (2025.3)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->puncc==0.8.0) (1.16.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->puncc==0.8.0) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->puncc==0.8.0) (1.17.0)
# Downloading puncc-0.8.0-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.8/70.8 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: puncc
# Successfully installed puncc-0.8.0
# Found existing installation: scikit-learn 1.8.0
# Uninstalling scikit-learn-1.8.0:
#   Successfully uninstalled scikit-learn-1.8.0
# Collecting scikit-learn==1.6.1
#   Downloading scikit_learn-1.6.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.6.1) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.6.1) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.6.1) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.6.1) (3.6.0)
# Downloading scikit_learn-1.6.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 86.4 MB/s eta 0:00:00
# Installing collected packages: scikit-learn
# Successfully installed scikit-learn-1.6.1
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.2 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 95.6 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# salib 1.5.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.36.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# shap 0.50.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4
# Collecting catboost==1.2.8
#   Downloading catboost-1.2.8-cp312-cp312-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from catboost==1.2.8) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from catboost==1.2.8) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from catboost==1.2.8) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.12/dist-packages (from catboost==1.2.8) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from catboost==1.2.8) (1.16.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from catboost==1.2.8) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from catboost==1.2.8) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost==1.2.8) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost==1.2.8) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost==1.2.8) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost==1.2.8) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost==1.2.8) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost==1.2.8) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost==1.2.8) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost==1.2.8) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost==1.2.8) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost==1.2.8) (3.3.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->catboost==1.2.8) (9.1.2)
# Downloading catboost-1.2.8-cp312-cp312-manylinux2014_x86_64.whl (99.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 8.4 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.8
# Collecting pytorch-tabnet2==4.5.3
#   Downloading pytorch_tabnet2-4.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting activations-plus>=0.1.1 (from pytorch-tabnet2==4.5.3)
#   Downloading activations_plus-0.1.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pytorch-tabnet2==4.5.3) (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from pytorch-tabnet2==4.5.3) (1.6.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from pytorch-tabnet2==4.5.3) (2.9.0+cpu)
# Collecting torcheval (from pytorch-tabnet2==4.5.3)
#   Downloading torcheval-0.0.7-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pytorch-tabnet2==4.5.3) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pytorch-tabnet2==4.5.3) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pytorch-tabnet2==4.5.3) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tabnet2==4.5.3) (3.20.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tabnet2==4.5.3) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tabnet2==4.5.3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tabnet2==4.5.3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tabnet2==4.5.3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tabnet2==4.5.3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-tabnet2==4.5.3) (2025.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->pytorch-tabnet2==4.5.3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->pytorch-tabnet2==4.5.3) (3.0.3)
# Downloading pytorch_tabnet2-4.5.3-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.9/70.9 kB 2.4 MB/s eta 0:00:00
# Downloading activations_plus-0.1.1-py3-none-any.whl (15 kB)
# Downloading torcheval-0.0.7-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.2/179.2 kB 7.1 MB/s eta 0:00:00
# Installing collected packages: torcheval, activations-plus, pytorch-tabnet2
# Successfully installed activations-plus-0.1.1 pytorch-tabnet2-4.5.3 torcheval-0.0.7

# %%
# Restart the runtime to apply changes
import os
os._exit(00)

# %% [markdown]
# # **Imports**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ngboost
import gpboost
from scipy.stats import randint
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.base import BaseEstimator, RegressorMixin
from sklearn.svm import SVR
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from gpboost import GPBoostRegressor
from ngboost import NGBRegressor
import optuna
import optunahub
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV
from interpret import show
from interpret.blackbox import LimeTabular, ShapKernel
from optuna.samplers import RandomSampler
import random
import time
from ngboost.distns import Normal
from ngboost.scores import LogScore
from scipy.stats import norm
from interpret import set_visualize_provider
from interpret.provider import InlineProvider
from interpret.glassbox import ExplainableBoostingRegressor
from interpret import show
import plotly.express as px
from io import BytesIO
from openpyxl import Workbook, load_workbook
import os
from openpyxl.drawing.image import Image as openpyxlImage
import warnings
import xlsxwriter
from openpyxl.drawing.image import Image
from pgbm.sklearn import HistGradientBoostingRegressor
import torch
from pgbm.torch import PGBM
import plotly.graph_objects as go
warnings.filterwarnings('ignore')
import pickle
import json
from pytorch_tabnet import TabNetRegressor

# %%
# Go to find & replace button and replace (Data_folder) with your folder name. Rename your train and test dataset as train.csv and test.csv.
# Modify the names of the feature in the below cell.
# Replace (Y_Label) with actual data label name.

# %%
feature_names = ['Qt', 'Qt-1', 'St-1']

# %%
train_data_path = "./drive/MyDrive/Data_folder/Data/train.csv"
test_data_path = "./drive/MyDrive/Data_folder/Data/test.csv"
train_data = pd.read_csv(train_data_path)
test_data = pd.read_csv(test_data_path)
print("Training data loaded successfully.")
print("Test data loaded successfully.")
# Out:
# Training data loaded successfully.
# Test data loaded successfully.

# %%
print("\nShape of training data:", train_data.shape)
print("First 5 rows of training data:\n", train_data.head(5))
print("\nShape of test data:", test_data.shape)
print("First 5 rows of test data:\n", test_data.head(5))
# Out:
# Shape of training data: (1095, 4)
# First 5 rows of training data:
#        Qt   Qt-1    St-1      St
# 0  12.40  11.80  5930.0  5630.0
# 1   7.93  12.40  5630.0  1960.0
# 2   5.66   7.93  1960.0   491.0
# 3   5.04   5.66   491.0   692.0
# 4   4.84   5.04   692.0   452.0
#
# Shape of test data: (365, 4)
# First 5 rows of test data:
#       Qt  Qt-1  St-1    St
# 0  5.27  5.49  45.0  44.0
# 1  5.13  5.27  44.0  29.0
# 2  4.84  5.13  29.0  23.0
# 3  5.04  4.84  23.0  26.0
# 4  5.21  5.04  26.0  30.0

# %%
X_train = train_data.iloc[:, :-1]
y_train = train_data.iloc[:, -1]
X_test = test_data.iloc[:, :-1]
y_test = test_data.iloc[:, -1]
x_test= X_test
print("\nShape of X_train:", X_train.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (1095, 3)
# Shape of y_train: (1095,)
# Shape of X_test: (365, 3)
# Shape of y_test: (365,)

# %%
# Apply z-score normalization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Print the first five rows of the normalized data
print("\nFirst five rows of normalized X_train:")
print(X_train[:5])

print("\nFirst five rows of normalized X_test:")
print(X_test[:5])
# Out:
# First five rows of normalized X_train:
# [[-0.13088871 -0.15525695  1.01508124]
#  [-0.31063021 -0.131129    0.95334642]
#  [-0.40190834 -0.31088224  0.19812377]
#  [-0.42683893 -0.40216633 -0.10417107]
#  [-0.43488105 -0.42709855 -0.06280874]]
#
# First five rows of normalized X_test:
# [[-0.41759048 -0.40900259 -0.19595018]
#  [-0.42321997 -0.4178495  -0.19615596]
#  [-0.43488105 -0.42347936 -0.1992427 ]
#  [-0.42683893 -0.4351412  -0.2004774 ]
#  [-0.42000312 -0.42709855 -0.19986005]]

# %% [markdown]
# # **Functions**

# %%
# Define the model classes
model_classes = {
    'Random Forest': RandomForestRegressor,
    'Gradient Boosting': GradientBoostingRegressor,
    'XGBoost': XGBRegressor,
    'LightGBM': LGBMRegressor,
    'GPBoost': GPBoostRegressor,
    'CatBoost': CatBoostRegressor,
    'HistGradientBoosting': HistGradientBoostingRegressor,
    'TabNet': TabNetRegressor,
    'NGBoost': NGBRegressor
}

# %%
def plot_best_scores(best_scores_ran, excel_file_path):
    # Extract the best pruner for each model based on RMSE and correlation coefficient
    best_rmse_scores = {}
    best_corr_coef_scores = {}

    for (model_name, pruner_name), scores in best_scores_ran.items():
        # Initialize if not already present
        if model_name not in best_rmse_scores:
            best_rmse_scores[model_name] = (scores['test_rmse'], pruner_name)
        if model_name not in best_corr_coef_scores:
            best_corr_coef_scores[model_name] = (scores['test_corr_coef'], pruner_name)

        # Update if better scores are found
        if scores['test_rmse'] < best_rmse_scores[model_name][0]:
            best_rmse_scores[model_name] = (scores['test_rmse'], pruner_name)
        if scores['test_corr_coef'] > best_corr_coef_scores[model_name][0]:
            best_corr_coef_scores[model_name] = (scores['test_corr_coef'], pruner_name)

    # Prepare data for plotting
    model_names_rmse = [f"{model} ({pruner})" for model, (rmse, pruner) in best_rmse_scores.items()]
    rmse_values = [rmse for rmse, _ in best_rmse_scores.values()]

    model_names_corr = [f"{model} ({pruner})" for model, (corr, pruner) in best_corr_coef_scores.items()]
    corr_values = [corr for corr, _ in best_corr_coef_scores.values()]

    # Plot RMSE
    plt.figure(figsize=(12, 6))
    bars_rmse = plt.bar(model_names_rmse, rmse_values, color='skyblue')

    # Highlight the best model
    best_rmse_index = np.argmin(rmse_values)
    bars_rmse[best_rmse_index].set_color('orange')

    # Annotate the bars with the RMSE scores
    for i, bar in enumerate(bars_rmse):
        plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() - 0.05,
                 f'{rmse_values[i]:.5f}', ha='center', va='bottom', color='black')

    # Add labels and title for the RMSE bar chart
    plt.xlabel('Model (Pruner)')
    plt.ylabel('Test RMSE')
    plt.title('Best Test RMSE for Each Model')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    rmse_image_path = 'rmse_plot.png'
    plt.savefig(rmse_image_path)
    plt.close()

    # Plot Correlation Coefficient
    plt.figure(figsize=(12, 6))
    bars_corr = plt.bar(model_names_corr, corr_values, color='lightgreen')

    # Highlight the best model
    best_corr_index = np.argmax(corr_values)
    bars_corr[best_corr_index].set_color('orange')

    # Annotate the bars with the correlation coefficient scores
    for i, bar in enumerate(bars_corr):
        plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() - 0.05,
                 f'{corr_values[i]:.5f}', ha='center', va='bottom', color='black')

    # Add labels and title for the correlation coefficient bar chart
    plt.xlabel('Model (Pruner)')
    plt.ylabel('Correlation Coefficient')
    plt.title('Best Correlation Coefficient for Each Model')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    corr_image_path = 'corr_plot.png'
    plt.savefig(corr_image_path)
    plt.close()

    # Load the existing Excel file
    workbook = load_workbook(excel_file_path)

    # Create a new sheet for the plots
    sheet_name = 'Best Models Plots'
    if sheet_name in workbook.sheetnames:
        sheet = workbook[sheet_name]
    else:
        sheet = workbook.create_sheet(title=sheet_name)

    # Insert images into the new Excel sheet
    img_rmse = Image(rmse_image_path)
    img_corr = Image(corr_image_path)

    # Insert images
    sheet.add_image(img_rmse, 'A1')
    sheet.add_image(img_corr, 'A20')  # Adjust the position as needed

    # Save the workbook
    workbook.save(excel_file_path)

    # Clean up the image files
    os.remove(rmse_image_path)
    os.remove(corr_image_path)

# Example usage
# plot_best_scores(best_scores_ran, 'path_to_your_excel_file.xlsx')

# %%
def generate_interpretml_explanations_summary_pruners(
    results_dict, X_train, y_train, X_test, feature_names, instance_indices=None, excel_file_path=None
):
    if instance_indices is None:
        instance_indices = range(len(X_test))
    elif isinstance(instance_indices, int):
        instance_indices = [instance_indices]

    valid_indices = [idx for idx in instance_indices if 0 <= idx < len(X_test)]
    if not valid_indices:
        print("No valid instance indices provided.")
        return

    if isinstance(X_test, pd.DataFrame):
        instances_to_explain = X_test.iloc[valid_indices]
    else:
        instances_to_explain = X_test[valid_indices]

    best_model_pruners = {}
    for model_key, model_info in results_dict.items():
        if isinstance(model_key, tuple):
            model_name, pruner_name = model_key
        else:
            model_name = model_key
            pruner_name = None

        best_score = model_info.get('best_score')
        if best_score is None:
            print(f"No 'best_score' found for {model_key}. Skipping this combination.")
            continue

        if model_name not in best_model_pruners:
            best_model_pruners[model_name] = {
                'pruner_name': pruner_name,
                'model_info': model_info,
                'best_score': best_score
            }
        else:
            current_best_score = best_model_pruners[model_name]['best_score']
            if best_score < current_best_score:
                best_model_pruners[model_name] = {
                    'pruner_name': pruner_name,
                    'model_info': model_info,
                    'best_score': best_score
                }

    for model_name, info in best_model_pruners.items():
        pruner_name = info['pruner_name']
        model_info = info['model_info']
        best_params = dict(model_info['best_params'])  # don't mutate original!
        model_class = model_classes.get(model_name)

        if model_class is None:
            print(f"Model {model_name} is not supported or not available.")
            continue

        if model_name == 'CatBoost':
            best_params['verbose'] = 0

        # ------- Main model fit logic ---------
        if model_name == "TabNet":
            # TabNet: reshape y, fit, flatten pred for LIME/SHAP, etc.
            y_train_tabnet = np.array(y_train).reshape(-1, 1)
            try:
                model = model_class(**{k: v for k, v in best_params.items() if k != "verbose"})
            except TypeError:
                model = model_class()
            model.fit(np.array(X_train), y_train_tabnet, max_epochs=100, patience=10, batch_size=1024, eval_set=[(np.array(X_train), y_train_tabnet)])
            def predict_fn(data):
                preds = model.predict(np.array(data))
                # flatten for interpreters
                return preds.flatten()
        else:
            try:
                model = model_class(**best_params)
            except TypeError:
                model = model_class()
            model.fit(X_train, y_train)
            def predict_fn(data):
                return model.predict(data)

        if isinstance(X_train, pd.DataFrame):
            data_for_explainer = X_train.values
        else:
            data_for_explainer = X_train

        if isinstance(instances_to_explain, pd.DataFrame):
            data_for_explanation = instances_to_explain.values
        else:
            data_for_explanation = instances_to_explain

        # Generate LIME explanations
        lime_explainer = LimeTabular(
            predict_fn,
            data=data_for_explainer,
            feature_names=feature_names,
            random_state=1,
            mode='regression'
        )
        lime_explanation = lime_explainer.explain_local(data_for_explanation)

        feature_importances_lime = {}
        num_instances = len(valid_indices)
        for idx in range(num_instances):
            explanation = lime_explanation.data(idx)
            for feature_name, feature_score in zip(explanation['names'], explanation['scores']):
                feature_importances_lime[feature_name] = feature_importances_lime.get(feature_name, 0) + abs(feature_score)
        feature_importances_lime = {k: v / num_instances for k, v in feature_importances_lime.items()}
        feature_importances_lime = {k: round(v, 3) for k, v in feature_importances_lime.items()}

        # Generate SHAP explanations using ShapKernel
        try:
            shap_explainer = ShapKernel(predict_fn, data_for_explainer, feature_names=feature_names)
            shap_explanation = shap_explainer.explain_local(data_for_explanation)

            feature_importances_shap = {}
            for idx in range(num_instances):
                explanation = shap_explanation.data(idx)
                for feature_name, feature_score in zip(explanation['names'], explanation['scores']):
                    feature_importances_shap[feature_name] = feature_importances_shap.get(feature_name, 0) + abs(feature_score)

            feature_importances_shap = {k: v / num_instances for k, v in feature_importances_shap.items()}
            feature_importances_shap = {k: round(v, 3) for k, v in feature_importances_shap.items()}
        except Exception as e:
            print(f"Could not compute SHAP values for model {model_name}: {e}")
            feature_importances_shap = {}

        # Plot LIME and SHAP feature importances side by side
        fig, axes = plt.subplots(1, 2, figsize=(34, 36))

        # Plot LIME feature importances
        lime_importances_df = pd.DataFrame.from_dict(
            feature_importances_lime, orient='index', columns=['importance']
        )
        lime_importances_df.sort_values(by='importance', ascending=False, inplace=True)
        lime_importances_df.plot(kind='bar', legend=False, color='skyblue', ax=axes[0])
        axes[0].set_title(f"LIME Feature Importances for {model_name}")
        axes[0].set_ylabel("Average Absolute Importance Score")
        axes[0].set_xlabel("Features")
        axes[0].tick_params(axis='x', rotation=45)

        for p in axes[0].patches:
            height = p.get_height()
            axes[0].annotate(f'{height:.3f}',
                             (p.get_x() + p.get_width() / 2., height),
                             ha='center', va='bottom', fontsize=8)

        # Plot SHAP feature importances
        shap_importances_df = pd.DataFrame.from_dict(
            feature_importances_shap, orient='index', columns=['importance']
        )
        shap_importances_df.sort_values(by='importance', ascending=False, inplace=True)
        shap_importances_df.plot(kind='bar', legend=False, color='orange', ax=axes[1])
        axes[1].set_title(f"SHAP Feature Importances for {model_name}")
        axes[1].set_ylabel("Average Absolute SHAP Value")
        axes[1].set_xlabel("Features")
        axes[1].tick_params(axis='x', rotation=45)

        for p in axes[1].patches:
            height = p.get_height()
            axes[1].annotate(f'{height:.3f}',
                             (p.get_x() + p.get_width() / 2., height),
                             ha='center', va='bottom', fontsize=8)

        plt.tight_layout()

        # Save plots as images
        image_path = f'feature_importances_{model_name}.png'
        fig.savefig(image_path)
        plt.close(fig)

        # Optionally insert images and scores into an Excel file
        if excel_file_path:
            workbook = load_workbook(excel_file_path)
            sheet_name = f'{model_name} Explanations'
            if sheet_name in workbook.sheetnames:
                sheet = workbook[sheet_name]
            else:
                sheet = workbook.create_sheet(title=sheet_name)

            # Insert images into the new Excel sheet
            img = Image(image_path)
            sheet.add_image(img, 'A1')

            # Create a new sheet for feature importance scores
            scores_sheet_name = f'{model_name} Scores'
            if scores_sheet_name in workbook.sheetnames:
                scores_sheet = workbook[scores_sheet_name]
            else:
                scores_sheet = workbook.create_sheet(title=scores_sheet_name)

            # Write LIME scores
            scores_sheet.append(['Feature', 'LIME Importance'])
            for feature, importance in feature_importances_lime.items():
                scores_sheet.append([feature, importance])

            # Write SHAP scores if available
            if feature_importances_shap:
                scores_sheet.append(['Feature', 'SHAP Importance'])
                for feature, importance in feature_importances_shap.items():
                    scores_sheet.append([feature, importance])

            # Save the workbook
            workbook.save(excel_file_path)

            # Clean up the image file
            os.remove(image_path)

# %% [markdown]
# # **Hyperparameter tuning using Autosampler by Optuna**

# %%
import joblib

def mseloss_objective(yhat, y, sample_weight=None):
    if not torch.is_tensor(yhat):
        yhat = torch.from_numpy(np.array(yhat)).float()
    if not torch.is_tensor(y):
        y = torch.from_numpy(np.array(y)).float()
    gradient = yhat - y
    hessian = torch.ones_like(yhat)
    return gradient, hessian


def rmseloss_metric(yhat, y, sample_weight=None):
    if not torch.is_tensor(yhat):
        yhat = torch.from_numpy(np.array(yhat)).float()
    if not torch.is_tensor(y):
        y = torch.from_numpy(np.array(y)).float()
    loss = torch.sqrt(torch.mean((yhat - y) ** 2))
    return loss


def hyperparameter_tuning_all(X_train, y_train, X_test, y_test, excel_path):

    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)

    # ================= NEW =================
    model_save_dir = "./drive/MyDrive/Data_folder/HyperParameter_Tuning/models"
    os.makedirs(model_save_dir, exist_ok=True)
    best_rmse_tracker = {}
    # =======================================

    models = {
        'Random Forest': (RandomForestRegressor, {
            'n_estimators': [100, 200, 300, 500, 700],
            'criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
            'max_depth': [None, 10, 20, 30, 40],
            'min_samples_split': [2, 5, 10, 0.01],
            'min_samples_leaf': [1, 3, 5, 0.01],
            'min_weight_fraction_leaf': [0.0, 0.01, 0.1, 0.2],
            'max_features': [1.0, 'sqrt', 'log2', 0.3, 0.5],
            'max_leaf_nodes': [None, 50, 100, 200],
            'min_impurity_decrease': [0.0, 0.01, 0.1, 0.2],
            'n_jobs': [-1],
            'random_state': [42],
            'verbose': [0],
            'warm_start': [False],
            'ccp_alpha': [0.0, 0.001, 0.01, 0.05, 0.1]
        }),
        'Gradient Boosting': (GradientBoostingRegressor, {
            'loss': ['squared_error', 'absolute_error', 'huber', 'quantile'],
            'learning_rate': [0.01, 0.05, 0.1, 0.2],
            'n_estimators': [100, 200, 300, 500, 700],
            'subsample': [1.0, 0.9, 0.7, 0.5],
            'criterion': ['friedman_mse', 'squared_error'],
            'min_samples_split': [2, 5, 10, 0.01],
            'min_samples_leaf': [1, 3, 5, 0.01],
            'min_weight_fraction_leaf': [0.0, 0.01, 0.05, 0.1],
            'max_depth': [3, 5, 7, 10],
            'min_impurity_decrease': [0.0, 0.01, 0.1],
            'init': [None],
            'random_state': [42],
            'max_features': [None, 'sqrt', 'log2', 0.5],
            'alpha': [0.9, 0.5, 0.1],
            'verbose': [0],
            'max_leaf_nodes': [None, 10, 30, 50],
            'warm_start': [False],
            'validation_fraction': [0.1],
            'n_iter_no_change': [None, 10, 20],
            'tol': [1e-4, 1e-3],
            'ccp_alpha': [0.0, 0.001, 0.01]
        }),
        'XGBoost': (XGBRegressor, {
            'n_estimators': [100, 200, 300, 400, 500],
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'max_depth': [3, 5, 7],
            'min_child_weight': [1, 3, 5],
            'gamma': [0, 0.1, 0.5, 1],
            'subsample': [0.5, 0.6, 0.7, 0.8, 0.9],
            'colsample_bytree': [0.5, 0.7, 0.9],
            'colsample_bylevel': [0.5, 0.7, 0.9],
            'reg_alpha': [0, 0.01, 0.1, 1],
            'reg_lambda': [0.1, 1, 5, 10],
            'objective': ['reg:squarederror'],
            'random_state': [42],
            'n_jobs': [-1]
        }),
        'LightGBM': (LGBMRegressor, {
            'n_estimators': [100, 200, 300, 400, 500],
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'num_leaves': [15, 31, 63],
            'max_depth': [3, 5, 7, -1],
            'min_child_samples': [1, 5, 10, 20],
            'subsample': [0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
            'colsample_bytree': [0.5, 0.7, 0.9, 1.0],
            'reg_alpha': [0, 0.01, 0.1, 1],
            'reg_lambda': [0, 0.1, 1, 10],
            'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1],
            'bagging_freq': [0, 1, 5],
            'objective': ['regression'],
            'random_state': [42],
            'n_jobs': [-1],
            'verbose': [-1]
        }),
        'GPBoost': (GPBoostRegressor, {
            'n_estimators': [100, 200, 300, 400, 500],
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'max_depth': [3, 5, 7, -1],
            'num_leaves': [15, 31, 63],
            'min_child_samples': [1, 5, 10, 20],
            'subsample': [0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
            'colsample_bytree': [0.5, 0.7, 0.9, 1.0],
            'reg_alpha': [0, 0.1, 0.5, 1.0],
            'reg_lambda': [0, 0.1, 0.5, 1.0],
            'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1],
            'random_state': [42],
            'n_jobs': [-1],
            'verbose': [-1]
        }),
        'CatBoost': (CatBoostRegressor, {
            'iterations': [200, 500, 1000],
            'learning_rate': [0.01, 0.03, 0.05, 0.1],
            'depth': [4, 6, 8, 10],
            'l2_leaf_reg': [1, 3, 5, 7, 9],
            'border_count': [32, 64, 128],
            'min_data_in_leaf': [1, 5, 10, 20],
            'rsm': [0.6, 0.8, 1.0],
            'bagging_temperature': [0, 1, 10],
            'random_seed': [42],
            'verbose': [0]
        }),
        'NGBoost': (NGBRegressor, {
            'n_estimators': [200, 500, 1000],
            'learning_rate': [0.01, 0.03, 0.05, 0.1],
            'natural_gradient': [True, False],
            'minibatch_frac': [0.5, 0.7, 0.9, 1.0],
            'col_sample': [0.5, 0.7, 0.9, 1.0],
            'Dist': [Normal],
            'Score': [LogScore],
            'random_state': [42],
            'verbose': [0]
        }),
        'TabNet': (TabNetRegressor, {
            'n_d': [8, 16, 32, 64],
            'n_a': [8, 16, 32, 64],
            'n_steps': [3, 5, 7, 10],
            'gamma': [1.0, 1.3, 1.5, 2.0],
            'lambda_sparse': [1e-4, 1e-3, 1e-2],
            'optimizer_params': [{'lr': 2e-2}], # Fixed learning rate as recommended
            'mask_type': ['sparsemax', 'entmax'],
            'n_shared': [1, 2, 3],
            'n_independent': [1, 2, 3],
            'scheduler_params': [{"step_size": 10, "gamma": 0.9}],
            'scheduler_fn': [torch.optim.lr_scheduler.StepLR],
            'seed': [42],
            'verbose': [0]
        }),
        'HistGradientBoosting': (HistGradientBoostingRegressor, {
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'max_iter': [100, 200, 300, 400, 500],
            'max_depth': [3, 5, 7, None],
            'min_samples_leaf': [5, 10, 20],
            'max_leaf_nodes': [15, 31, 63, None],
            'l2_regularization': [0.0, 0.1, 0.5, 1.0],
            'max_bins': [64, 128, 255],
            'early_stopping': [True, False],
            'validation_fraction': [0.1, 0.2],
            'n_iter_no_change': [5, 10, 15],
            'loss': ['squared_error'],
            'random_state': [42],
            'verbose': [0]
        }),
        'PGBM': (PGBM, {})
    }

    pruners = [
        optuna.pruners.MedianPruner(),
        optuna.pruners.NopPruner(),
        optuna.pruners.PatientPruner(optuna.pruners.MedianPruner(), patience=3),
        optuna.pruners.PercentilePruner(25.0),
        optuna.pruners.SuccessiveHalvingPruner(),
        optuna.pruners.HyperbandPruner(),
        optuna.pruners.ThresholdPruner(lower=0.1),
        optuna.pruners.WilcoxonPruner()
    ]

    best_scores = {}
    predictions_df = pd.DataFrame({'Actual': y_test})
    timing_records = []

    for model_name, (model_class, param_space) in models.items():

        rmse_trial_history = {p.__class__.__name__: [] for p in pruners}

        for pruner in pruners:
            pruner_name = pruner.__class__.__name__
            print(f"Running Optuna for {model_name} with {pruner_name}...")
            start_time = time.time()

            best_rmse_tracker[(model_name, pruner_name)] = np.inf

            sampler = optunahub.load_module("samplers/auto_sampler").AutoSampler()
            study = optuna.create_study(direction='minimize', sampler=sampler, pruner=pruner)

            if model_name == 'PGBM':

                def pgbm_objective(trial):
                    params = {
                            'n_estimators': trial.suggest_categorical('n_estimators', [100, 200, 300, 500]),
                            'learning_rate': trial.suggest_categorical('learning_rate', [0.01, 0.05, 0.1, 0.15]),
                            'max_leaves': trial.suggest_int('max_leaves', 15, 63),
                            'min_split_gain': trial.suggest_categorical('min_split_gain', [0.0, 0.1, 0.5, 1.0]),
                            'reg_lambda': trial.suggest_categorical('reg_lambda', [0.1, 1.0, 5.0, 10.0]),
                            'feature_fraction': trial.suggest_categorical('feature_fraction', [0.5, 0.7, 0.9, 1.0]),
                            'bagging_fraction': trial.suggest_categorical('bagging_fraction', [0.5, 0.7, 0.9, 1.0]),
                            'tree_correlation': trial.suggest_categorical('tree_correlation', [0.0, 0.1, 0.2, 0.3]),
                            'min_data_in_leaf': trial.suggest_categorical('min_data_in_leaf', [3, 5, 10, 20]),
                            'max_bin': trial.suggest_categorical('max_bin', [64, 128, 256]),
                            'distribution': trial.suggest_categorical('distribution', ['normal', 'studentt', 'laplace']),
                            'objective': 'mse',
                            'metric': 'rmse',
                            'random_state': 42,
                            'verbose': 0
                        }

                    model = PGBM()
                    model.train((X_train, y_train),
                                objective=mseloss_objective,
                                metric=rmseloss_metric,
                                params=params)

                    y_pred = model.predict(X_test)
                    mse = mean_squared_error(y_test, y_pred)
                    rmse = np.sqrt(mse)

                    rmse_trial_history[pruner_name].append(rmse)

                    # ===== SAVE BEST MODEL =====
                    if rmse < best_rmse_tracker[(model_name, pruner_name)]:
                        best_rmse_tracker[(model_name, pruner_name)] = rmse
                        save_path = os.path.join(
                            model_save_dir,
                            f"{model_name}_{pruner_name}_BEST.pkl"
                        )
                        joblib.dump(model, save_path)

                    return mse

                study.optimize(pgbm_objective, n_trials=50)

            else:

                def objective(trial):
                    params = {}
                    for key, values in param_space.items():
                        params[key] = trial.suggest_categorical(key, values)

                    model = model_class(**params)

                    if model_name == 'TabNet':
                        model.fit(X_train, y_train.reshape(-1, 1))
                    else:
                        model.fit(X_train, y_train)


                    y_pred = model.predict(X_test)

                    if model_name == 'TabNet':
                        y_pred = y_pred.ravel()

                    mse = mean_squared_error(y_test, y_pred)

                    rmse = np.sqrt(mse)

                    rmse_trial_history[pruner_name].append(rmse)

                    # ===== SAVE BEST MODEL =====
                    if rmse < best_rmse_tracker[(model_name, pruner_name)]:
                        best_rmse_tracker[(model_name, pruner_name)] = rmse
                        save_path = os.path.join(
                            model_save_dir,
                            f"{model_name}_{pruner_name}_BEST.pkl"
                        )
                        joblib.dump(model, save_path)

                    return mse

                study.optimize(objective, n_trials=50)

            elapsed_time = time.time() - start_time

            # Load frozen model (NO RETRAIN)
            best_model = joblib.load(
                os.path.join(model_save_dir, f"{model_name}_{pruner_name}_BEST.pkl")
            )

            y_pred = best_model.predict(X_test)

            if model_name == 'TabNet':
                y_pred = y_pred.ravel()

            mse = mean_squared_error(y_test, y_pred)
            rmse = np.sqrt(mse)
            corr_coef = np.corrcoef(y_test, y_pred)[0, 1]


            predictions_df[f'{model_name}_{pruner_name}_Predicted'] = y_pred

            best_scores[(model_name, pruner_name)] = {
                'best_score': mse,
                'best_params': study.best_params,
                'test_mse': mse,
                'test_rmse': rmse,
                'test_corr_coef': corr_coef,
                'pruner': pruner_name
            }

            timing_records.append({
                'Model': model_name,
                'Pruner': pruner_name,
                'Tuning_Time_Seconds': elapsed_time
            })

        # RMSE plots & Excel writing (UNCHANGED)
        rmse_df = pd.DataFrame(rmse_trial_history)
        rmse_df.insert(0, "Trial", np.arange(1, len(rmse_df) + 1))

        with pd.ExcelWriter(excel_path, engine='openpyxl', mode='a', if_sheet_exists='replace') as writer:
            rmse_df.to_excel(writer, sheet_name=f"RMSE_Trials_{model_name}", index=False)
        # ================= SAVE RMSE PLOT =================
        plot_dir = os.path.dirname(excel_path)
        plot_path = os.path.join(plot_dir, f"RMSE_Trials_{model_name}.png")

        plt.figure(figsize=(10, 6))
        for pruner_name, values in rmse_trial_history.items():
            if len(values) > 0:   # <-- important safety check
                plt.plot(values, label=pruner_name, linewidth=2)

        plt.title(f"RMSE Variation Over Trials\n{model_name}")
        plt.xlabel("Trial Number")
        plt.ylabel("RMSE")
        plt.legend(loc="center left", bbox_to_anchor=(1.02, 0.5))
        plt.tight_layout()

        plt.savefig(plot_path, dpi=100, bbox_inches="tight")
        plt.close()

        # ================= INSERT PLOT INTO EXCEL =================
        wb = load_workbook(excel_path)
        ws = wb[f"RMSE_Trials_{model_name}"]

        img = Image(plot_path)
        img.anchor = "J2"
        ws.add_image(img)

        wb.save(excel_path)

    timing_df = pd.DataFrame(timing_records)

    with pd.ExcelWriter(excel_path, engine='openpyxl', mode='a') as writer:
        predictions_df.to_excel(writer, sheet_name='Predictions', index=False)
        timing_df.to_excel(writer, sheet_name='Tuning_Time', index=False)

    return best_scores


best_scores_autosampler = hyperparameter_tuning_all(X_train, y_train, X_test, y_test, "./drive/MyDrive/Data_folder/HyperParameter_Tuning/test.xlsx")
# Out:
# Running Optuna for Random Forest with MedianPruner...
# [I 2026-01-16 20:10:38,553] A new study created in memory with name: no-name-36666eb0-00b1-4d44-86e6-339b71052e20
# [I 2026-01-16 20:10:41,105] Trial 0 finished with value: 932650.9785281194 and parameters: {'n_estimators': 300, 'criterion': 'squared_error', 'max_depth': 30, 'min_samples_split': 10, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.1, 'max_features': 1.0, 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 0 with value: 932650.9785281194.
# [I 2026-01-16 20:10:41,484] Trial 1 finished with value: 721689.6799299048 and parameters: {'n_estimators': 100, 'criterion': 'friedman_mse', 'max_depth': 20, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.2, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 1 with value: 721689.6799299048.
# [I 2026-01-16 20:10:43,475] Trial 2 finished with value: 178093.08110397743 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 2 with value: 178093.08110397743.
# [I 2026-01-16 20:10:45,148] Trial 3 finished with value: 180162.7749341808 and parameters: {'n_estimators': 700, 'criterion': 'squared_error', 'max_depth': None, 'min_samples_split': 5, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.5, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}. Best is trial 2 with value: 178093.08110397743.
# [I 2026-01-16 20:10:45,420] Trial 4 finished with value: 1000704.8359768802 and parameters: {'n_estimators': 100, 'criterion': 'friedman_mse', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.1, 'max_features': 1.0, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 2 with value: 178093.08110397743.
# [I 2026-01-16 20:10:47,500] Trial 5 finished with value: 270070.08962860546 and parameters: {'n_estimators': 700, 'criterion': 'poisson', 'max_depth': 40, 'min_samples_split': 0.01, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 2 with value: 178093.08110397743.
# [I 2026-01-16 20:10:49,142] Trial 6 finished with value: 243515.30229858728 and parameters: {'n_estimators': 300, 'criterion': 'squared_error', 'max_depth': 30, 'min_samples_split': 10, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 1.0, 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}. Best is trial 2 with value: 178093.08110397743.
# [I 2026-01-16 20:10:51,001] Trial 7 finished with value: 904633.3806647658 and parameters: {'n_estimators': 500, 'criterion': 'friedman_mse', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.1, 'max_features': 1.0, 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 2 with value: 178093.08110397743.
# [I 2026-01-16 20:10:52,359] Trial 8 finished with value: 222080.1813706052 and parameters: {'n_estimators': 500, 'criterion': 'squared_error', 'max_depth': 30, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 2 with value: 178093.08110397743.
# [I 2026-01-16 20:10:52,602] Trial 9 finished with value: 716783.2079296436 and parameters: {'n_estimators': 100, 'criterion': 'poisson', 'max_depth': 10, 'min_samples_split': 0.01, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.2, 'max_features': 'sqrt', 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}. Best is trial 2 with value: 178093.08110397743.
# [I 2026-01-16 20:10:54,500] Trial 10 finished with value: 157960.29136991865 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 10 with value: 157960.29136991865.
# [I 2026-01-16 20:10:55,707] Trial 11 finished with value: 208764.14449913474 and parameters: {'n_estimators': 200, 'criterion': 'absolute_error', 'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 10 with value: 157960.29136991865.
# [I 2026-01-16 20:10:57,521] Trial 12 finished with value: 196121.9549842322 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 10, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 10 with value: 157960.29136991865.
# [I 2026-01-16 20:10:59,331] Trial 13 finished with value: 131830.0393253032 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 20, 'min_samples_split': 5, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.5, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 13 with value: 131830.0393253032.
# [I 2026-01-16 20:11:01,080] Trial 14 finished with value: 127746.49273903693 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 20, 'min_samples_split': 5, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.5, 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}. Best is trial 14 with value: 127746.49273903693.
# [I 2026-01-16 20:11:03,984] Trial 15 finished with value: 127746.49273903693 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 30, 'min_samples_split': 5, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 'log2', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}. Best is trial 14 with value: 127746.49273903693.
# [I 2026-01-16 20:11:11,882] Trial 16 finished with value: 129035.04754159336 and parameters: {'n_estimators': 700, 'criterion': 'absolute_error', 'max_depth': 30, 'min_samples_split': 5, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}. Best is trial 14 with value: 127746.49273903693.
# [I 2026-01-16 20:11:12,601] Trial 17 finished with value: 243634.75392019568 and parameters: {'n_estimators': 300, 'criterion': 'poisson', 'max_depth': 30, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 'log2', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}. Best is trial 14 with value: 127746.49273903693.
# [I 2026-01-16 20:11:14,426] Trial 18 finished with value: 136204.03545024528 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': None, 'min_samples_split': 5, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.0, 'max_features': 'log2', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}. Best is trial 14 with value: 127746.49273903693.
# [I 2026-01-16 20:11:15,089] Trial 19 finished with value: 700572.703023576 and parameters: {'n_estimators': 300, 'criterion': 'squared_error', 'max_depth': 30, 'min_samples_split': 5, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.2, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 14 with value: 127746.49273903693.
# [I 2026-01-16 20:11:18,220] Trial 20 finished with value: 127529.06899497197 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 30, 'min_samples_split': 5, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 'log2', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 20 with value: 127529.06899497197.
# [I 2026-01-16 20:11:19,084] Trial 21 finished with value: 700572.703023576 and parameters: {'n_estimators': 300, 'criterion': 'friedman_mse', 'max_depth': 30, 'min_samples_split': 5, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.2, 'max_features': 'log2', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 20 with value: 127529.06899497197.
# [I 2026-01-16 20:11:20,862] Trial 22 finished with value: 127544.70876998875 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 30, 'min_samples_split': 5, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.01, 'max_features': 'log2', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 20 with value: 127529.06899497197.
# [I 2026-01-16 20:11:22,052] Trial 23 finished with value: 129697.5337059853 and parameters: {'n_estimators': 200, 'criterion': 'absolute_error', 'max_depth': 30, 'min_samples_split': 10, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.01, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 20 with value: 127529.06899497197.
# [I 2026-01-16 20:11:23,887] Trial 24 finished with value: 127520.95817183223 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 30, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 24 with value: 127520.95817183223.
# [I 2026-01-16 20:11:25,640] Trial 25 finished with value: 128655.7979680991 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 30, 'min_samples_split': 0.01, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.01, 'max_features': 'log2', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 24 with value: 127520.95817183223.
# [I 2026-01-16 20:11:27,404] Trial 26 finished with value: 127529.06899497197 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': None, 'min_samples_split': 5, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 24 with value: 127520.95817183223.
# [I 2026-01-16 20:11:29,158] Trial 27 finished with value: 127520.95817183223 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 40, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 24 with value: 127520.95817183223.
# [I 2026-01-16 20:11:32,563] Trial 28 finished with value: 127242.00111104643 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 40, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 28 with value: 127242.00111104643.
# [I 2026-01-16 20:11:33,610] Trial 29 finished with value: 244274.75116938676 and parameters: {'n_estimators': 300, 'criterion': 'poisson', 'max_depth': 40, 'min_samples_split': 0.01, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.01, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 28 with value: 127242.00111104643.
# [I 2026-01-16 20:11:35,570] Trial 30 finished with value: 127242.00111104643 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 20, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 28 with value: 127242.00111104643.
# [I 2026-01-16 20:11:37,512] Trial 31 finished with value: 127242.00111104643 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 40, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 28 with value: 127242.00111104643.
# [I 2026-01-16 20:11:39,538] Trial 32 finished with value: 127226.28941880252 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 10, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.5, 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 32 with value: 127226.28941880252.
# [I 2026-01-16 20:11:40,953] Trial 33 finished with value: 187268.35758098116 and parameters: {'n_estimators': 200, 'criterion': 'absolute_error', 'max_depth': 40, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 0.5, 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 32 with value: 127226.28941880252.
# [I 2026-01-16 20:11:41,943] Trial 34 finished with value: 1018736.5179024959 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 10, 'min_samples_split': 0.01, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.2, 'max_features': 0.5, 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 32 with value: 127226.28941880252.
# [I 2026-01-16 20:11:44,030] Trial 35 finished with value: 136219.7571410077 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 20, 'min_samples_split': 5, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 32 with value: 127226.28941880252.
# [I 2026-01-16 20:11:47,444] Trial 36 finished with value: 127246.58803041745 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.5, 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 32 with value: 127226.28941880252.
# [I 2026-01-16 20:11:48,207] Trial 37 finished with value: 228273.3604195823 and parameters: {'n_estimators': 300, 'criterion': 'squared_error', 'max_depth': 40, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 32 with value: 127226.28941880252.
# [I 2026-01-16 20:11:50,136] Trial 38 finished with value: 127248.98482600806 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 20, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.3, 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 32 with value: 127226.28941880252.
# [I 2026-01-16 20:11:50,886] Trial 39 finished with value: 227950.75661083325 and parameters: {'n_estimators': 300, 'criterion': 'friedman_mse', 'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 'sqrt', 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 32 with value: 127226.28941880252.
# [I 2026-01-16 20:11:53,889] Trial 40 finished with value: 136227.5625922558 and parameters: {'n_estimators': 500, 'criterion': 'absolute_error', 'max_depth': 40, 'min_samples_split': 0.01, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.3, 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 32 with value: 127226.28941880252.
# [I 2026-01-16 20:11:55,748] Trial 41 finished with value: 127248.95967982542 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.5, 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 32 with value: 127226.28941880252.
# [I 2026-01-16 20:12:02,393] Trial 42 finished with value: 125917.57166500202 and parameters: {'n_estimators': 700, 'criterion': 'absolute_error', 'max_depth': 20, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 42 with value: 125917.57166500202.
# [I 2026-01-16 20:12:03,703] Trial 43 finished with value: 127974.09687871713 and parameters: {'n_estimators': 200, 'criterion': 'absolute_error', 'max_depth': 20, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 42 with value: 125917.57166500202.
# [I 2026-01-16 20:12:08,278] Trial 44 finished with value: 125647.84335013448 and parameters: {'n_estimators': 700, 'criterion': 'absolute_error', 'max_depth': 20, 'min_samples_split': 0.01, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.01, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 44 with value: 125647.84335013448.
# [I 2026-01-16 20:12:13,502] Trial 45 finished with value: 126517.97350916456 and parameters: {'n_estimators': 700, 'criterion': 'absolute_error', 'max_depth': 20, 'min_samples_split': 0.01, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.5, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 44 with value: 125647.84335013448.
# [I 2026-01-16 20:12:18,760] Trial 46 finished with value: 125647.84335013448 and parameters: {'n_estimators': 700, 'criterion': 'absolute_error', 'max_depth': 20, 'min_samples_split': 0.01, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.01, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 44 with value: 125647.84335013448.
# [I 2026-01-16 20:12:23,218] Trial 47 finished with value: 126517.97350916456 and parameters: {'n_estimators': 700, 'criterion': 'absolute_error', 'max_depth': 20, 'min_samples_split': 0.01, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.5, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 44 with value: 125647.84335013448.
# [I 2026-01-16 20:12:28,966] Trial 48 finished with value: 125647.84335013448 and parameters: {'n_estimators': 700, 'criterion': 'absolute_error', 'max_depth': 20, 'min_samples_split': 0.01, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.01, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 44 with value: 125647.84335013448.
# [I 2026-01-16 20:12:33,620] Trial 49 finished with value: 125647.84335013448 and parameters: {'n_estimators': 700, 'criterion': 'absolute_error', 'max_depth': 30, 'min_samples_split': 0.01, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.01, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 44 with value: 125647.84335013448.
# [I 2026-01-16 20:12:34,009] A new study created in memory with name: no-name-6ef8562c-73e3-4952-a594-c6f523d16bf3
# Running Optuna for Random Forest with NopPruner...
# [I 2026-01-16 20:12:34,830] Trial 0 finished with value: 228266.08005017147 and parameters: {'n_estimators': 300, 'criterion': 'squared_error', 'max_depth': 40, 'min_samples_split': 0.01, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.3, 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 0 with value: 228266.08005017147.
# [I 2026-01-16 20:12:39,416] Trial 1 finished with value: 135252.6222927479 and parameters: {'n_estimators': 700, 'criterion': 'absolute_error', 'max_depth': 20, 'min_samples_split': 0.01, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.0, 'max_features': 'log2', 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 1 with value: 135252.6222927479.
# [I 2026-01-16 20:12:44,624] Trial 2 finished with value: 115871.6198151319 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': None, 'min_samples_split': 5, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:12:48,212] Trial 3 finished with value: 931249.246991257 and parameters: {'n_estimators': 700, 'criterion': 'absolute_error', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.2, 'max_features': 1.0, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:12:48,507] Trial 4 finished with value: 203831.69599487504 and parameters: {'n_estimators': 100, 'criterion': 'squared_error', 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.0, 'max_features': 1.0, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:12:48,738] Trial 5 finished with value: 716783.2079296436 and parameters: {'n_estimators': 100, 'criterion': 'poisson', 'max_depth': 30, 'min_samples_split': 10, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.2, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:12:49,214] Trial 6 finished with value: 1252898.6630126145 and parameters: {'n_estimators': 200, 'criterion': 'poisson', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.1, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:12:50,541] Trial 7 finished with value: 160177.23309987588 and parameters: {'n_estimators': 200, 'criterion': 'absolute_error', 'max_depth': None, 'min_samples_split': 0.01, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.0, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:12:50,780] Trial 8 finished with value: 716783.1986103259 and parameters: {'n_estimators': 100, 'criterion': 'poisson', 'max_depth': 10, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.2, 'max_features': 0.5, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:12:51,421] Trial 9 finished with value: 156894.0933080404 and parameters: {'n_estimators': 100, 'criterion': 'absolute_error', 'max_depth': 10, 'min_samples_split': 0.01, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.0, 'max_features': 0.3, 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:12:55,601] Trial 10 finished with value: 136121.77160696738 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 20, 'min_samples_split': 5, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:12:57,070] Trial 11 finished with value: 188596.23337965543 and parameters: {'n_estimators': 300, 'criterion': 'squared_error', 'max_depth': None, 'min_samples_split': 5, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.0, 'max_features': 1.0, 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:13:01,749] Trial 12 finished with value: 169652.97914361916 and parameters: {'n_estimators': 700, 'criterion': 'absolute_error', 'max_depth': 20, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 'sqrt', 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:13:03,989] Trial 13 finished with value: 1022229.2157022101 and parameters: {'n_estimators': 700, 'criterion': 'absolute_error', 'max_depth': 40, 'min_samples_split': 0.01, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.2, 'max_features': 'log2', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:13:04,657] Trial 14 finished with value: 201173.39206460697 and parameters: {'n_estimators': 300, 'criterion': 'poisson', 'max_depth': None, 'min_samples_split': 5, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.5, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:13:06,324] Trial 15 finished with value: 321757.38436351466 and parameters: {'n_estimators': 700, 'criterion': 'poisson', 'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.0, 'max_features': 'log2', 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:13:07,923] Trial 16 finished with value: 1018079.7315612274 and parameters: {'n_estimators': 500, 'criterion': 'absolute_error', 'max_depth': 40, 'min_samples_split': 5, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.2, 'max_features': 0.3, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:13:10,856] Trial 17 finished with value: 136658.6432863536 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 10, 'min_samples_split': 0.01, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.0, 'max_features': 'log2', 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:13:18,901] Trial 18 finished with value: 115884.53058327845 and parameters: {'n_estimators': 700, 'criterion': 'absolute_error', 'max_depth': None, 'min_samples_split': 0.01, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:13:19,954] Trial 19 finished with value: 926802.1778668457 and parameters: {'n_estimators': 200, 'criterion': 'absolute_error', 'max_depth': None, 'min_samples_split': 0.01, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.2, 'max_features': 1.0, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:13:21,886] Trial 20 finished with value: 196125.7233680707 and parameters: {'n_estimators': 700, 'criterion': 'poisson', 'max_depth': 40, 'min_samples_split': 2, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:13:23,361] Trial 21 finished with value: 309551.5181317757 and parameters: {'n_estimators': 200, 'criterion': 'absolute_error', 'max_depth': 20, 'min_samples_split': 0.01, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.1, 'max_features': 'log2', 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:13:26,311] Trial 22 finished with value: 137586.88422363315 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': None, 'min_samples_split': 0.01, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.3, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:13:30,735] Trial 23 finished with value: 126429.23055132417 and parameters: {'n_estimators': 700, 'criterion': 'absolute_error', 'max_depth': 20, 'min_samples_split': 0.01, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.01, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:13:35,097] Trial 24 finished with value: 125877.87858351383 and parameters: {'n_estimators': 700, 'criterion': 'absolute_error', 'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.3, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:13:41,138] Trial 25 finished with value: 134379.3432844076 and parameters: {'n_estimators': 700, 'criterion': 'absolute_error', 'max_depth': None, 'min_samples_split': 5, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:13:42,682] Trial 26 finished with value: 212319.3713780011 and parameters: {'n_estimators': 700, 'criterion': 'friedman_mse', 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.3, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:13:43,428] Trial 27 finished with value: 269794.9565832179 and parameters: {'n_estimators': 300, 'criterion': 'squared_error', 'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.0, 'max_features': 0.3, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:13:44,829] Trial 28 finished with value: 189947.33988671275 and parameters: {'n_estimators': 500, 'criterion': 'friedman_mse', 'max_depth': None, 'min_samples_split': 5, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 2 with value: 115871.6198151319.
# [I 2026-01-16 20:13:53,345] Trial 29 finished with value: 115790.77142647581 and parameters: {'n_estimators': 700, 'criterion': 'absolute_error', 'max_depth': 30, 'min_samples_split': 0.01, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 29 with value: 115790.77142647581.
# [I 2026-01-16 20:14:01,972] Trial 30 finished with value: 128964.95603341331 and parameters: {'n_estimators': 700, 'criterion': 'absolute_error', 'max_depth': None, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}. Best is trial 29 with value: 115790.77142647581.
# [I 2026-01-16 20:14:05,432] Trial 31 finished with value: 127350.94727311979 and parameters: {'n_estimators': 500, 'criterion': 'absolute_error', 'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.3, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 29 with value: 115790.77142647581.
# [I 2026-01-16 20:14:10,636] Trial 32 finished with value: 133690.68850410802 and parameters: {'n_estimators': 700, 'criterion': 'absolute_error', 'max_depth': 30, 'min_samples_split': 0.01, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.3, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 29 with value: 115790.77142647581.
# [I 2026-01-16 20:14:17,773] Trial 33 finished with value: 115916.93639060299 and parameters: {'n_estimators': 700, 'criterion': 'absolute_error', 'max_depth': 40, 'min_samples_split': 0.01, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 29 with value: 115790.77142647581.
# [I 2026-01-16 20:14:26,752] Trial 34 finished with value: 115790.77142647581 and parameters: {'n_estimators': 700, 'criterion': 'absolute_error', 'max_depth': 30, 'min_samples_split': 0.01, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 29 with value: 115790.77142647581.
# [I 2026-01-16 20:14:28,833] Trial 35 finished with value: 268991.33354748285 and parameters: {'n_estimators': 700, 'criterion': 'squared_error', 'max_depth': 30, 'min_samples_split': 0.01, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 29 with value: 115790.77142647581.
# [I 2026-01-16 20:14:30,858] Trial 36 finished with value: 191250.07518028078 and parameters: {'n_estimators': 700, 'criterion': 'friedman_mse', 'max_depth': None, 'min_samples_split': 0.01, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 29 with value: 115790.77142647581.
# [I 2026-01-16 20:14:32,845] Trial 37 finished with value: 191249.59845107855 and parameters: {'n_estimators': 700, 'criterion': 'friedman_mse', 'max_depth': 30, 'min_samples_split': 5, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.0, 'max_features': 1.0, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 29 with value: 115790.77142647581.
# [I 2026-01-16 20:14:38,915] Trial 38 finished with value: 135142.77438769417 and parameters: {'n_estimators': 700, 'criterion': 'absolute_error', 'max_depth': 30, 'min_samples_split': 0.01, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 29 with value: 115790.77142647581.
# [I 2026-01-16 20:14:42,321] Trial 39 finished with value: 115703.8554346153 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 30, 'min_samples_split': 0.01, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 39 with value: 115703.8554346153.
# [I 2026-01-16 20:14:44,258] Trial 40 finished with value: 127243.50008468669 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 30, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 'log2', 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 39 with value: 115703.8554346153.
# [I 2026-01-16 20:14:46,301] Trial 41 finished with value: 117594.78725743355 and parameters: {'n_estimators': 200, 'criterion': 'absolute_error', 'max_depth': 30, 'min_samples_split': 0.01, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}. Best is trial 39 with value: 115703.8554346153.
# [I 2026-01-16 20:14:51,348] Trial 42 finished with value: 115703.8554346153 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': None, 'min_samples_split': 10, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 39 with value: 115703.8554346153.
# [I 2026-01-16 20:14:54,638] Trial 43 finished with value: 115720.24705263715 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': None, 'min_samples_split': 10, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}. Best is trial 39 with value: 115703.8554346153.
# [I 2026-01-16 20:14:58,096] Trial 44 finished with value: 115703.5673107638 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': None, 'min_samples_split': 10, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}. Best is trial 44 with value: 115703.5673107638.
# [I 2026-01-16 20:15:01,213] Trial 45 finished with value: 115744.86228005982 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': None, 'min_samples_split': 10, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}. Best is trial 44 with value: 115703.5673107638.
# [I 2026-01-16 20:15:03,934] Trial 46 finished with value: 136487.61571813363 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': None, 'min_samples_split': 10, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.5, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}. Best is trial 44 with value: 115703.5673107638.
# [I 2026-01-16 20:15:06,276] Trial 47 finished with value: 928114.6592073545 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 30, 'min_samples_split': 10, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.2, 'max_features': 1.0, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}. Best is trial 44 with value: 115703.5673107638.
# [I 2026-01-16 20:15:08,588] Trial 48 finished with value: 172765.3792567182 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': None, 'min_samples_split': 0.01, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.1, 'max_features': 1.0, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 44 with value: 115703.5673107638.
# [I 2026-01-16 20:15:11,918] Trial 49 finished with value: 115703.8554346153 and parameters: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': None, 'min_samples_split': 10, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 44 with value: 115703.5673107638.
# [I 2026-01-16 20:15:12,097] A new study created in memory with name: no-name-8c20287b-269e-4898-88d0-57e0d753d11a
# Running Optuna for Random Forest with PatientPruner...
# [I 2026-01-16 20:15:13,331] Trial 0 finished with value: 691095.891310864 and parameters: {'n_estimators': 500, 'criterion': 'squared_error', 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.2, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}. Best is trial 0 with value: 691095.891310864.
# [I 2026-01-16 20:15:14,175] Trial 1 finished with value: 227002.68243198836 and parameters: {'n_estimators': 300, 'criterion': 'friedman_mse', 'max_depth': 10, 'min_samples_split': 0.01, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.5, 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}. Best is trial 1 with value: 227002.68243198836.
# [I 2026-01-16 20:15:14,869] Trial 2 finished with value: 695352.1699713789 and parameters: {'n_estimators': 300, 'criterion': 'poisson', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.2, 'max_features': 0.3, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}. Best is trial 1 with value: 227002.68243198836.
# ...
# Training on CPU
# [I 2026-01-17 00:23:09,039] Trial 11 finished with value: 182239.2671778916 and parameters: {'n_estimators': 300, 'learning_rate': 0.01, 'max_leaves': 22, 'min_split_gain': 0.0, 'reg_lambda': 0.1, 'feature_fraction': 1.0, 'bagging_fraction': 0.7, 'tree_correlation': 0.0, 'min_data_in_leaf': 3, 'max_bin': 128, 'distribution': 'normal'}. Best is trial 2 with value: 113226.43852004048.
# Training on CPU
# [I 2026-01-17 00:23:11,974] Trial 12 finished with value: 113377.6039062864 and parameters: {'n_estimators': 100, 'learning_rate': 0.05, 'max_leaves': 30, 'min_split_gain': 0.5, 'reg_lambda': 10.0, 'feature_fraction': 1.0, 'bagging_fraction': 0.5, 'tree_correlation': 0.2, 'min_data_in_leaf': 5, 'max_bin': 256, 'distribution': 'normal'}. Best is trial 2 with value: 113226.43852004048.
# Training on CPU
# [I 2026-01-17 00:23:16,716] Trial 13 finished with value: 154252.6586075946 and parameters: {'n_estimators': 100, 'learning_rate': 0.05, 'max_leaves': 25, 'min_split_gain': 0.5, 'reg_lambda': 0.1, 'feature_fraction': 1.0, 'bagging_fraction': 0.5, 'tree_correlation': 0.1, 'min_data_in_leaf': 5, 'max_bin': 256, 'distribution': 'normal'}. Best is trial 2 with value: 113226.43852004048.
# Training on CPU
# [I 2026-01-17 00:23:19,227] Trial 14 finished with value: 112767.98987612204 and parameters: {'n_estimators': 100, 'learning_rate': 0.05, 'max_leaves': 32, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 1.0, 'bagging_fraction': 0.5, 'tree_correlation': 0.2, 'min_data_in_leaf': 10, 'max_bin': 256, 'distribution': 'laplace'}. Best is trial 14 with value: 112767.98987612204.
# Training on CPU
# [I 2026-01-17 00:23:38,840] Trial 15 finished with value: 378371.73218020453 and parameters: {'n_estimators': 500, 'learning_rate': 0.05, 'max_leaves': 38, 'min_split_gain': 0.0, 'reg_lambda': 1.0, 'feature_fraction': 1.0, 'bagging_fraction': 0.5, 'tree_correlation': 0.2, 'min_data_in_leaf': 20, 'max_bin': 256, 'distribution': 'laplace'}. Best is trial 14 with value: 112767.98987612204.
# Training on CPU
# [I 2026-01-17 00:23:41,687] Trial 16 finished with value: 113129.70137951696 and parameters: {'n_estimators': 100, 'learning_rate': 0.05, 'max_leaves': 25, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 1.0, 'bagging_fraction': 1.0, 'tree_correlation': 0.2, 'min_data_in_leaf': 10, 'max_bin': 64, 'distribution': 'laplace'}. Best is trial 14 with value: 112767.98987612204.
# Training on CPU
# [I 2026-01-17 00:23:43,088] Trial 17 finished with value: 397624.9673743108 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_leaves': 19, 'min_split_gain': 0.0, 'reg_lambda': 5.0, 'feature_fraction': 1.0, 'bagging_fraction': 0.5, 'tree_correlation': 0.2, 'min_data_in_leaf': 10, 'max_bin': 64, 'distribution': 'laplace'}. Best is trial 14 with value: 112767.98987612204.
# Training on CPU
# [I 2026-01-17 00:23:47,949] Trial 18 finished with value: 88289.97372563762 and parameters: {'n_estimators': 200, 'learning_rate': 0.05, 'max_leaves': 24, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 1.0, 'bagging_fraction': 0.7, 'tree_correlation': 0.2, 'min_data_in_leaf': 10, 'max_bin': 64, 'distribution': 'laplace'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:23:52,823] Trial 19 finished with value: 177168.92674892728 and parameters: {'n_estimators': 200, 'learning_rate': 0.05, 'max_leaves': 20, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 1.0, 'bagging_fraction': 0.7, 'tree_correlation': 0.0, 'min_data_in_leaf': 20, 'max_bin': 128, 'distribution': 'laplace'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:23:58,588] Trial 20 finished with value: 106843.57833746893 and parameters: {'n_estimators': 200, 'learning_rate': 0.05, 'max_leaves': 23, 'min_split_gain': 0.0, 'reg_lambda': 5.0, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'tree_correlation': 0.2, 'min_data_in_leaf': 10, 'max_bin': 64, 'distribution': 'studentt'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:24:08,799] Trial 21 finished with value: 174414.73459260972 and parameters: {'n_estimators': 500, 'learning_rate': 0.05, 'max_leaves': 19, 'min_split_gain': 0.0, 'reg_lambda': 5.0, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'tree_correlation': 0.2, 'min_data_in_leaf': 10, 'max_bin': 64, 'distribution': 'normal'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:24:14,976] Trial 22 finished with value: 229664.7464437766 and parameters: {'n_estimators': 200, 'learning_rate': 0.15, 'max_leaves': 26, 'min_split_gain': 1.0, 'reg_lambda': 5.0, 'feature_fraction': 1.0, 'bagging_fraction': 0.7, 'tree_correlation': 0.2, 'min_data_in_leaf': 10, 'max_bin': 64, 'distribution': 'studentt'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:24:22,435] Trial 23 finished with value: 142118.63609081612 and parameters: {'n_estimators': 200, 'learning_rate': 0.05, 'max_leaves': 36, 'min_split_gain': 0.1, 'reg_lambda': 5.0, 'feature_fraction': 0.7, 'bagging_fraction': 1.0, 'tree_correlation': 0.2, 'min_data_in_leaf': 10, 'max_bin': 64, 'distribution': 'studentt'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:24:27,460] Trial 24 finished with value: 317992.1048198451 and parameters: {'n_estimators': 200, 'learning_rate': 0.05, 'max_leaves': 28, 'min_split_gain': 0.0, 'reg_lambda': 5.0, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'tree_correlation': 0.1, 'min_data_in_leaf': 20, 'max_bin': 64, 'distribution': 'studentt'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:24:32,078] Trial 25 finished with value: 659893.2894592797 and parameters: {'n_estimators': 200, 'learning_rate': 0.05, 'max_leaves': 22, 'min_split_gain': 0.0, 'reg_lambda': 5.0, 'feature_fraction': 0.5, 'bagging_fraction': 0.9, 'tree_correlation': 0.2, 'min_data_in_leaf': 10, 'max_bin': 256, 'distribution': 'studentt'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:24:36,289] Trial 26 finished with value: 137492.15649998738 and parameters: {'n_estimators': 200, 'learning_rate': 0.01, 'max_leaves': 31, 'min_split_gain': 0.0, 'reg_lambda': 1.0, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'tree_correlation': 0.2, 'min_data_in_leaf': 10, 'max_bin': 64, 'distribution': 'studentt'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:24:38,601] Trial 27 finished with value: 113093.3415260723 and parameters: {'n_estimators': 100, 'learning_rate': 0.05, 'max_leaves': 39, 'min_split_gain': 1.0, 'reg_lambda': 10.0, 'feature_fraction': 1.0, 'bagging_fraction': 0.5, 'tree_correlation': 0.2, 'min_data_in_leaf': 10, 'max_bin': 128, 'distribution': 'laplace'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:24:42,251] Trial 28 finished with value: 104707.62879465728 and parameters: {'n_estimators': 100, 'learning_rate': 0.05, 'max_leaves': 44, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 1.0, 'bagging_fraction': 0.7, 'tree_correlation': 0.0, 'min_data_in_leaf': 10, 'max_bin': 256, 'distribution': 'laplace'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:24:47,175] Trial 29 finished with value: 418985.10580364795 and parameters: {'n_estimators': 200, 'learning_rate': 0.05, 'max_leaves': 29, 'min_split_gain': 1.0, 'reg_lambda': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.7, 'tree_correlation': 0.2, 'min_data_in_leaf': 10, 'max_bin': 64, 'distribution': 'laplace'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:24:52,019] Trial 30 finished with value: 104707.62879465728 and parameters: {'n_estimators': 100, 'learning_rate': 0.05, 'max_leaves': 47, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 1.0, 'bagging_fraction': 0.7, 'tree_correlation': 0.0, 'min_data_in_leaf': 10, 'max_bin': 256, 'distribution': 'normal'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:24:55,609] Trial 31 finished with value: 104707.62879465728 and parameters: {'n_estimators': 100, 'learning_rate': 0.05, 'max_leaves': 46, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 1.0, 'bagging_fraction': 0.7, 'tree_correlation': 0.0, 'min_data_in_leaf': 10, 'max_bin': 256, 'distribution': 'normal'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:24:59,184] Trial 32 finished with value: 104707.62879465728 and parameters: {'n_estimators': 100, 'learning_rate': 0.05, 'max_leaves': 50, 'min_split_gain': 0.1, 'reg_lambda': 10.0, 'feature_fraction': 1.0, 'bagging_fraction': 0.7, 'tree_correlation': 0.0, 'min_data_in_leaf': 10, 'max_bin': 256, 'distribution': 'normal'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:25:04,939] Trial 33 finished with value: 1449714.4755804678 and parameters: {'n_estimators': 100, 'learning_rate': 0.05, 'max_leaves': 48, 'min_split_gain': 0.0, 'reg_lambda': 0.1, 'feature_fraction': 0.5, 'bagging_fraction': 0.7, 'tree_correlation': 0.0, 'min_data_in_leaf': 5, 'max_bin': 256, 'distribution': 'laplace'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:25:08,009] Trial 34 finished with value: 164884.40311318432 and parameters: {'n_estimators': 100, 'learning_rate': 0.05, 'max_leaves': 43, 'min_split_gain': 0.0, 'reg_lambda': 1.0, 'feature_fraction': 0.9, 'bagging_fraction': 0.5, 'tree_correlation': 0.0, 'min_data_in_leaf': 10, 'max_bin': 256, 'distribution': 'normal'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:25:39,751] Trial 35 finished with value: 390700.13018978474 and parameters: {'n_estimators': 500, 'learning_rate': 0.1, 'max_leaves': 42, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'tree_correlation': 0.0, 'min_data_in_leaf': 10, 'max_bin': 256, 'distribution': 'normal'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:25:46,031] Trial 36 finished with value: 117394.0778010856 and parameters: {'n_estimators': 100, 'learning_rate': 0.05, 'max_leaves': 48, 'min_split_gain': 0.0, 'reg_lambda': 1.0, 'feature_fraction': 1.0, 'bagging_fraction': 0.7, 'tree_correlation': 0.0, 'min_data_in_leaf': 10, 'max_bin': 256, 'distribution': 'laplace'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:25:50,115] Trial 37 finished with value: 108304.18361566516 and parameters: {'n_estimators': 200, 'learning_rate': 0.05, 'max_leaves': 23, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 0.9, 'bagging_fraction': 0.7, 'tree_correlation': 0.2, 'min_data_in_leaf': 5, 'max_bin': 64, 'distribution': 'laplace'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:25:55,549] Trial 38 finished with value: 147940.84642718284 and parameters: {'n_estimators': 100, 'learning_rate': 0.15, 'max_leaves': 32, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 1.0, 'bagging_fraction': 0.7, 'tree_correlation': 0.0, 'min_data_in_leaf': 10, 'max_bin': 256, 'distribution': 'normal'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:26:01,957] Trial 39 finished with value: 166358.81448378862 and parameters: {'n_estimators': 100, 'learning_rate': 0.05, 'max_leaves': 51, 'min_split_gain': 0.0, 'reg_lambda': 5.0, 'feature_fraction': 1.0, 'bagging_fraction': 0.9, 'tree_correlation': 0.2, 'min_data_in_leaf': 10, 'max_bin': 256, 'distribution': 'normal'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:26:04,375] Trial 40 finished with value: 147381.2265254089 and parameters: {'n_estimators': 200, 'learning_rate': 0.01, 'max_leaves': 20, 'min_split_gain': 0.5, 'reg_lambda': 10.0, 'feature_fraction': 1.0, 'bagging_fraction': 0.7, 'tree_correlation': 0.2, 'min_data_in_leaf': 10, 'max_bin': 64, 'distribution': 'laplace'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:26:09,942] Trial 41 finished with value: 205386.97162330587 and parameters: {'n_estimators': 100, 'learning_rate': 0.05, 'max_leaves': 48, 'min_split_gain': 0.1, 'reg_lambda': 10.0, 'feature_fraction': 1.0, 'bagging_fraction': 0.7, 'tree_correlation': 0.0, 'min_data_in_leaf': 3, 'max_bin': 256, 'distribution': 'normal'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:26:14,093] Trial 42 finished with value: 104707.62879465728 and parameters: {'n_estimators': 100, 'learning_rate': 0.05, 'max_leaves': 51, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 1.0, 'bagging_fraction': 0.7, 'tree_correlation': 0.3, 'min_data_in_leaf': 10, 'max_bin': 256, 'distribution': 'normal'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:26:17,036] Trial 43 finished with value: 118500.01895734068 and parameters: {'n_estimators': 100, 'learning_rate': 0.05, 'max_leaves': 58, 'min_split_gain': 0.1, 'reg_lambda': 10.0, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'tree_correlation': 0.0, 'min_data_in_leaf': 10, 'max_bin': 256, 'distribution': 'laplace'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:26:20,806] Trial 44 finished with value: 120377.51041728952 and parameters: {'n_estimators': 100, 'learning_rate': 0.05, 'max_leaves': 43, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 1.0, 'bagging_fraction': 1.0, 'tree_correlation': 0.0, 'min_data_in_leaf': 10, 'max_bin': 128, 'distribution': 'normal'}. Best is trial 18 with value: 88289.97372563762.
# Training on CPU
# [I 2026-01-17 00:26:23,744] Trial 45 finished with value: 86773.2618088813 and parameters: {'n_estimators': 100, 'learning_rate': 0.05, 'max_leaves': 34, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 1.0, 'bagging_fraction': 0.7, 'tree_correlation': 0.0, 'min_data_in_leaf': 10, 'max_bin': 64, 'distribution': 'studentt'}. Best is trial 45 with value: 86773.2618088813.
# Training on CPU
# [I 2026-01-17 00:26:32,440] Trial 46 finished with value: 92967.72027434525 and parameters: {'n_estimators': 200, 'learning_rate': 0.05, 'max_leaves': 49, 'min_split_gain': 0.5, 'reg_lambda': 10.0, 'feature_fraction': 1.0, 'bagging_fraction': 0.5, 'tree_correlation': 0.0, 'min_data_in_leaf': 10, 'max_bin': 256, 'distribution': 'laplace'}. Best is trial 45 with value: 86773.2618088813.
# Training on CPU
# [I 2026-01-17 00:26:33,927] Trial 47 finished with value: 273990.23949029425 and parameters: {'n_estimators': 100, 'learning_rate': 0.05, 'max_leaves': 28, 'min_split_gain': 0.0, 'reg_lambda': 10.0, 'feature_fraction': 0.5, 'bagging_fraction': 0.7, 'tree_correlation': 0.0, 'min_data_in_leaf': 10, 'max_bin': 64, 'distribution': 'studentt'}. Best is trial 45 with value: 86773.2618088813.
# Training on CPU
# [I 2026-01-17 00:26:43,478] Trial 48 finished with value: 92967.72027434525 and parameters: {'n_estimators': 200, 'learning_rate': 0.05, 'max_leaves': 52, 'min_split_gain': 0.5, 'reg_lambda': 10.0, 'feature_fraction': 1.0, 'bagging_fraction': 0.5, 'tree_correlation': 0.1, 'min_data_in_leaf': 10, 'max_bin': 256, 'distribution': 'laplace'}. Best is trial 45 with value: 86773.2618088813.
# Training on CPU
# [I 2026-01-17 00:26:59,402] Trial 49 finished with value: 112639.45620524722 and parameters: {'n_estimators': 300, 'learning_rate': 0.05, 'max_leaves': 57, 'min_split_gain': 0.5, 'reg_lambda': 10.0, 'feature_fraction': 1.0, 'bagging_fraction': 0.5, 'tree_correlation': 0.0, 'min_data_in_leaf': 10, 'max_bin': 256, 'distribution': 'laplace'}. Best is trial 45 with value: 86773.2618088813.

# %%
best_scores_autosampler

# %% [markdown]
# # **Best Model Analysis**

# %%
def get_best_models_and_predict(best_scores_autosampler, X_train, y_train, X_test, y_test, file_path):
    # Convert input data to NumPy arrays
    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)

    # Mapping for model creation based on dictionary keys
    model_mapping = {
        'Random Forest': RandomForestRegressor,
        'Gradient Boosting': GradientBoostingRegressor,
        'XGBoost': XGBRegressor,
        'LightGBM': LGBMRegressor,
        'CatBoost': CatBoostRegressor,
        'GPBoost': GPBoostRegressor,
        'NGBoost': NGBRegressor,
        'TabNet': TabNetRegressor,
        'HistGradientBoosting': HistGradientBoostingRegressor,
        'PGBM': PGBM  # PGBM is handled separately
    }

    # Dictionary to store the best model for each type
    best_models = {}

    # Iterate over the dictionary to find the best pruner for each model type
    for (model_name, pruner), params in best_scores_autosampler.items():
        current_score = params.get('test_mse', np.inf)
        if model_name not in best_models or current_score < best_models[model_name]['score']:
            best_models[model_name] = {
                'score': current_score,
                'params': params['best_params'],
                'pruner': pruner
            }

    # Prepare a DataFrame to store predictions
    df = pd.read_csv(file_path)

    # Iterate over the best models to train and predict
    for model_name, model_info in best_models.items():
        best_params = model_info['params']
        model_class = model_mapping.get(model_name)

        if model_class is None:
            print(f"Model {model_name} is not supported or not available.")
            continue

        # Handle specific parameters or settings for model if needed
        if model_name == 'CatBoost':
            best_params.pop('verbose', None)  # Remove 'verbose' for CatBoost

        # Create an instance of the best model with the best parameters
        if model_name == 'PGBM':
            model = model_class()
            model.train((X_train, y_train), objective=mseloss_objective, metric=rmseloss_metric, params=best_params)
            predictions = model.predict(X_test)
        elif model_name == 'TabNet':
            model = model_class(**best_params)
            model.fit(X_train, y_train.reshape(-1, 1))
            predictions = model.predict(X_test)
            predictions = predictions.ravel()
        else:
            model = model_class(**best_params)
            model.fit(X_train, y_train)
            predictions = model.predict(X_test)

        # Add predictions to the DataFrame
        df[f'{model_name} Predictions'] = predictions

        # Plot actual vs. predicted
        plt.figure(figsize=(10, 6))
        plt.scatter(y_test, predictions, alpha=0.6)
        plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', color='red', lw=2)
        plt.xlabel("Actual Y_Label")
        plt.ylabel("Predicted Y_Label")
        plt.title(f"Actual vs. Predicted Values ({model_name})")
        plt.grid(True)
        plt.tight_layout()

        # Save the plot temporarily
        plot_path = f'temp_plot_{model_name}.png'
        plt.savefig(plot_path)
        plt.close()

    # ✅ NEW OUTPUT DIRECTORY
    output_dir = "./drive/MyDrive/Data_folder/HyperParameter_Tuning/"
    os.makedirs(output_dir, exist_ok=True)

    output_excel_path = os.path.join(
        output_dir,
        os.path.basename(file_path).replace('.csv', '_results.xlsx')
    )

    # Save predictions and plots to Excel
    with pd.ExcelWriter(output_excel_path, engine='xlsxwriter') as writer:
        # Write data to Excel
        df.to_excel(writer, sheet_name='Data', index=False)

        # Get the xlsxwriter objects
        workbook = writer.book

        # Insert each plot into a separate worksheet
        for model_name in best_models.keys():
            short_model_name = ''.join([word[0] for word in model_name.split()])
            sheet_name = f'{short_model_name}_Plot'

            worksheet = workbook.add_worksheet(sheet_name)
            writer.sheets[sheet_name] = worksheet
            plot_path = f'temp_plot_{model_name}.png'
            worksheet.insert_image('A1', plot_path)

    # Clean up temporary plot files
    for model_name in best_models.keys():
        os.remove(f'temp_plot_{model_name}.png')

    return df, best_models

# Call the function
df, best_models = get_best_models_and_predict(best_scores_autosampler, X_train, y_train, X_test, y_test, "./drive/MyDrive/Data_folder/Data/test.csv")
# Out:
# 0:	learn: 4774.5604879	total: 6.26ms	remaining: 1.24s
# 1:	learn: 4694.0209493	total: 10.1ms	remaining: 1s
# 2:	learn: 4611.9270228	total: 13.4ms	remaining: 878ms
# 3:	learn: 4535.3073007	total: 17.5ms	remaining: 857ms
# 4:	learn: 4464.0064133	total: 18.9ms	remaining: 737ms
# 5:	learn: 4391.4263384	total: 22.2ms	remaining: 719ms
# 6:	learn: 4323.4154989	total: 25.6ms	remaining: 706ms
# 7:	learn: 4255.8829308	total: 26ms	remaining: 623ms
# 8:	learn: 4193.2257650	total: 27ms	remaining: 572ms
# 9:	learn: 4131.8818022	total: 29ms	remaining: 552ms
# 10:	learn: 4073.8046698	total: 33ms	remaining: 566ms
# 11:	learn: 4014.9106484	total: 35ms	remaining: 548ms
# 12:	learn: 3960.9601613	total: 38.6ms	remaining: 555ms
# 13:	learn: 3906.5853858	total: 42.1ms	remaining: 559ms
# 14:	learn: 3856.7636388	total: 43ms	remaining: 530ms
# 15:	learn: 3806.7997604	total: 43.7ms	remaining: 502ms
# 16:	learn: 3758.5385054	total: 47.6ms	remaining: 513ms
# 17:	learn: 3711.5923220	total: 48ms	remaining: 485ms
# 18:	learn: 3670.2868221	total: 48.8ms	remaining: 465ms
# 19:	learn: 3627.3055346	total: 52.2ms	remaining: 470ms
# 20:	learn: 3583.2531977	total: 57.6ms	remaining: 491ms
# 21:	learn: 3541.5550098	total: 64.2ms	remaining: 519ms
# 22:	learn: 3507.4668697	total: 65.5ms	remaining: 504ms
# 23:	learn: 3467.1712649	total: 70.9ms	remaining: 520ms
# 24:	learn: 3432.9235938	total: 79.6ms	remaining: 557ms
# 25:	learn: 3396.3384610	total: 87.5ms	remaining: 585ms
# 26:	learn: 3361.7471574	total: 95.4ms	remaining: 611ms
# 27:	learn: 3328.0196143	total: 101ms	remaining: 623ms
# 28:	learn: 3295.4172277	total: 109ms	remaining: 642ms
# 29:	learn: 3262.3936052	total: 115ms	remaining: 653ms
# 30:	learn: 3231.6271114	total: 123ms	remaining: 668ms
# 31:	learn: 3200.7743315	total: 129ms	remaining: 677ms
# 32:	learn: 3172.2156668	total: 136ms	remaining: 689ms
# 33:	learn: 3144.5827999	total: 143ms	remaining: 696ms
# 34:	learn: 3117.8441049	total: 150ms	remaining: 707ms
# 35:	learn: 3092.6343481	total: 156ms	remaining: 711ms
# 36:	learn: 3066.8280293	total: 164ms	remaining: 720ms
# 37:	learn: 3041.9330441	total: 170ms	remaining: 724ms
# 38:	learn: 3017.6003406	total: 177ms	remaining: 731ms
# 39:	learn: 2996.1934227	total: 184ms	remaining: 734ms
# 40:	learn: 2974.1877584	total: 184ms	remaining: 715ms
# 41:	learn: 2953.4478232	total: 192ms	remaining: 724ms
# 42:	learn: 2933.6577058	total: 204ms	remaining: 746ms
# 43:	learn: 2913.3659549	total: 211ms	remaining: 748ms
# 44:	learn: 2894.5950902	total: 219ms	remaining: 756ms
# 45:	learn: 2876.9988370	total: 225ms	remaining: 755ms
# 46:	learn: 2860.0988617	total: 233ms	remaining: 759ms
# 47:	learn: 2842.3045575	total: 239ms	remaining: 758ms
# 48:	learn: 2825.9420926	total: 247ms	remaining: 760ms
# 49:	learn: 2809.1518773	total: 253ms	remaining: 759ms
# 50:	learn: 2793.8397569	total: 260ms	remaining: 761ms
# 51:	learn: 2778.6953712	total: 266ms	remaining: 757ms
# 52:	learn: 2764.0811521	total: 274ms	remaining: 760ms
# 53:	learn: 2749.5164921	total: 280ms	remaining: 756ms
# 54:	learn: 2734.6287721	total: 285ms	remaining: 753ms
# 55:	learn: 2721.5497750	total: 291ms	remaining: 749ms
# 56:	learn: 2708.5701179	total: 299ms	remaining: 751ms
# 57:	learn: 2695.9075000	total: 305ms	remaining: 747ms
# 58:	learn: 2684.4839981	total: 311ms	remaining: 743ms
# 59:	learn: 2673.7525488	total: 319ms	remaining: 744ms
# 60:	learn: 2663.3737472	total: 325ms	remaining: 741ms
# 61:	learn: 2651.8560643	total: 334ms	remaining: 742ms
# 62:	learn: 2641.0986966	total: 340ms	remaining: 739ms
# 63:	learn: 2630.5036272	total: 347ms	remaining: 738ms
# 64:	learn: 2620.3987723	total: 354ms	remaining: 735ms
# 65:	learn: 2610.0704396	total: 361ms	remaining: 733ms
# 66:	learn: 2601.0779387	total: 367ms	remaining: 729ms
# 67:	learn: 2593.0228233	total: 374ms	remaining: 725ms
# 68:	learn: 2584.1916297	total: 375ms	remaining: 713ms
# 69:	learn: 2575.4491024	total: 381ms	remaining: 708ms
# 70:	learn: 2567.7217729	total: 386ms	remaining: 701ms
# 71:	learn: 2560.3874769	total: 393ms	remaining: 699ms
# 72:	learn: 2551.6908949	total: 401ms	remaining: 698ms
# 73:	learn: 2544.6245589	total: 411ms	remaining: 700ms
# 74:	learn: 2536.9398204	total: 417ms	remaining: 696ms
# 75:	learn: 2529.8370638	total: 423ms	remaining: 691ms
# 76:	learn: 2522.8218061	total: 427ms	remaining: 683ms
# 77:	learn: 2516.4301228	total: 431ms	remaining: 675ms
# 78:	learn: 2510.1183611	total: 435ms	remaining: 667ms
# 79:	learn: 2504.5474907	total: 439ms	remaining: 659ms
# 80:	learn: 2498.3552580	total: 443ms	remaining: 651ms
# 81:	learn: 2492.5319121	total: 447ms	remaining: 643ms
# 82:	learn: 2486.5942628	total: 448ms	remaining: 632ms
# 83:	learn: 2481.8058295	total: 452ms	remaining: 624ms
# 84:	learn: 2476.3357494	total: 456ms	remaining: 617ms
# 85:	learn: 2471.4846790	total: 460ms	remaining: 610ms
# 86:	learn: 2466.9349691	total: 464ms	remaining: 603ms
# 87:	learn: 2461.8423348	total: 468ms	remaining: 595ms
# 88:	learn: 2456.6153176	total: 472ms	remaining: 588ms
# 89:	learn: 2451.7058091	total: 476ms	remaining: 581ms
# 90:	learn: 2447.1964708	total: 480ms	remaining: 574ms
# 91:	learn: 2443.0548134	total: 483ms	remaining: 568ms
# 92:	learn: 2439.2569532	total: 494ms	remaining: 569ms
# 93:	learn: 2434.5603721	total: 498ms	remaining: 562ms
# 94:	learn: 2431.2764123	total: 499ms	remaining: 551ms
# 95:	learn: 2427.8957170	total: 503ms	remaining: 545ms
# 96:	learn: 2424.2069939	total: 514ms	remaining: 546ms
# 97:	learn: 2420.2327216	total: 521ms	remaining: 542ms
# 98:	learn: 2417.0120318	total: 526ms	remaining: 536ms
# 99:	learn: 2414.0963862	total: 532ms	remaining: 532ms
# 100:	learn: 2410.5687293	total: 539ms	remaining: 528ms
# 101:	learn: 2407.6303873	total: 546ms	remaining: 524ms
# 102:	learn: 2404.6164649	total: 552ms	remaining: 520ms
# 103:	learn: 2402.0814987	total: 553ms	remaining: 510ms
# 104:	learn: 2398.9986404	total: 560ms	remaining: 507ms
# 105:	learn: 2396.3592744	total: 561ms	remaining: 497ms
# 106:	learn: 2393.9393911	total: 568ms	remaining: 493ms
# 107:	learn: 2391.3716875	total: 573ms	remaining: 488ms
# 108:	learn: 2388.9939707	total: 581ms	remaining: 485ms
# 109:	learn: 2386.7955010	total: 586ms	remaining: 479ms
# 110:	learn: 2384.5100623	total: 589ms	remaining: 472ms
# 111:	learn: 2382.4868397	total: 590ms	remaining: 463ms
# 112:	learn: 2381.8799008	total: 593ms	remaining: 457ms
# 113:	learn: 2379.4960121	total: 597ms	remaining: 451ms
# 114:	learn: 2377.1799977	total: 602ms	remaining: 445ms
# 115:	learn: 2375.4187771	total: 607ms	remaining: 440ms
# 116:	learn: 2373.2933245	total: 614ms	remaining: 435ms
# 117:	learn: 2371.3007266	total: 621ms	remaining: 432ms
# 118:	learn: 2368.7299249	total: 632ms	remaining: 430ms
# 119:	learn: 2367.0911408	total: 638ms	remaining: 426ms
# 120:	learn: 2365.4862440	total: 646ms	remaining: 422ms
# 121:	learn: 2363.5353636	total: 652ms	remaining: 417ms
# 122:	learn: 2361.7750803	total: 660ms	remaining: 413ms
# 123:	learn: 2360.1709987	total: 668ms	remaining: 409ms
# 124:	learn: 2359.5184312	total: 675ms	remaining: 405ms
# 125:	learn: 2357.7599926	total: 683ms	remaining: 401ms
# 126:	learn: 2356.4995415	total: 691ms	remaining: 397ms
# 127:	learn: 2354.5936427	total: 697ms	remaining: 392ms
# 128:	learn: 2353.8852639	total: 705ms	remaining: 388ms
# 129:	learn: 2352.2911760	total: 712ms	remaining: 383ms
# 130:	learn: 2350.8871331	total: 719ms	remaining: 379ms
# 131:	learn: 2349.4519064	total: 725ms	remaining: 374ms
# 132:	learn: 2348.9670232	total: 733ms	remaining: 369ms
# 133:	learn: 2347.4064006	total: 740ms	remaining: 365ms
# 134:	learn: 2346.3775204	total: 741ms	remaining: 357ms
# 135:	learn: 2345.6064472	total: 745ms	remaining: 350ms
# 136:	learn: 2344.4160192	total: 753ms	remaining: 346ms
# 137:	learn: 2343.2054962	total: 760ms	remaining: 341ms
# 138:	learn: 2341.8112992	total: 767ms	remaining: 337ms
# 139:	learn: 2341.5061980	total: 776ms	remaining: 332ms
# 140:	learn: 2340.6050004	total: 778ms	remaining: 325ms
# 141:	learn: 2339.1543093	total: 782ms	remaining: 319ms
# 142:	learn: 2338.1071525	total: 788ms	remaining: 314ms
# 143:	learn: 2336.3886667	total: 790ms	remaining: 307ms
# 144:	learn: 2335.4694424	total: 800ms	remaining: 304ms
# 145:	learn: 2334.5389974	total: 807ms	remaining: 298ms
# 146:	learn: 2333.3682851	total: 813ms	remaining: 293ms
# 147:	learn: 2332.5906454	total: 821ms	remaining: 288ms
# 148:	learn: 2331.8052579	total: 826ms	remaining: 283ms
# 149:	learn: 2331.2896908	total: 833ms	remaining: 278ms
# 150:	learn: 2330.3917319	total: 841ms	remaining: 273ms
# 151:	learn: 2329.5527384	total: 849ms	remaining: 268ms
# 152:	learn: 2328.6256231	total: 857ms	remaining: 263ms
# 153:	learn: 2327.5940114	total: 865ms	remaining: 258ms
# 154:	learn: 2326.2846426	total: 871ms	remaining: 253ms
# 155:	learn: 2325.3879875	total: 878ms	remaining: 248ms
# 156:	learn: 2325.0752049	total: 885ms	remaining: 242ms
# 157:	learn: 2323.6718461	total: 891ms	remaining: 237ms
# 158:	learn: 2323.0264363	total: 897ms	remaining: 231ms
# 159:	learn: 2322.3057101	total: 905ms	remaining: 226ms
# 160:	learn: 2321.1714966	total: 913ms	remaining: 221ms
# 161:	learn: 2320.9995269	total: 922ms	remaining: 216ms
# 162:	learn: 2320.0244990	total: 930ms	remaining: 211ms
# 163:	learn: 2319.3183737	total: 936ms	remaining: 205ms
# 164:	learn: 2318.7569088	total: 942ms	remaining: 200ms
# 165:	learn: 2318.5423151	total: 946ms	remaining: 194ms
# 166:	learn: 2318.4500533	total: 946ms	remaining: 187ms
# 167:	learn: 2317.8832387	total: 951ms	remaining: 181ms
# 168:	learn: 2317.0998065	total: 956ms	remaining: 175ms
# 169:	learn: 2316.1084520	total: 962ms	remaining: 170ms
# 170:	learn: 2315.5748208	total: 968ms	remaining: 164ms
# 171:	learn: 2315.3784890	total: 974ms	remaining: 158ms
# 172:	learn: 2314.9125880	total: 977ms	remaining: 152ms
# 173:	learn: 2314.3486235	total: 984ms	remaining: 147ms
# 174:	learn: 2314.1118526	total: 993ms	remaining: 142ms
# 175:	learn: 2313.9100090	total: 1s	remaining: 136ms
# 176:	learn: 2313.3552993	total: 1.01s	remaining: 131ms
# 177:	learn: 2312.0893174	total: 1.01s	remaining: 125ms
# 178:	learn: 2311.7018568	total: 1.01s	remaining: 119ms
# 179:	learn: 2311.1034584	total: 1.02s	remaining: 113ms
# 180:	learn: 2310.9869141	total: 1.02s	remaining: 107ms
# 181:	learn: 2310.3291457	total: 1.03s	remaining: 102ms
# 182:	learn: 2309.7566057	total: 1.03s	remaining: 95.9ms
# 183:	learn: 2309.7099983	total: 1.03s	remaining: 89.8ms
# 184:	learn: 2309.1688804	total: 1.03s	remaining: 84ms
# 185:	learn: 2309.0114275	total: 1.04s	remaining: 78.2ms
# 186:	learn: 2308.3108036	total: 1.04s	remaining: 72.5ms
# 187:	learn: 2307.8828168	total: 1.04s	remaining: 66.8ms
# 188:	learn: 2307.2347787	total: 1.05s	remaining: 61ms
# 189:	learn: 2306.9948204	total: 1.05s	remaining: 55.4ms
# 190:	learn: 2305.5547003	total: 1.05s	remaining: 49.7ms
# 191:	learn: 2305.5124218	total: 1.06s	remaining: 44.1ms
# 192:	learn: 2304.9639956	total: 1.06s	remaining: 38.5ms
# 193:	learn: 2304.7575113	total: 1.06s	remaining: 33ms
# 194:	learn: 2304.1793201	total: 1.07s	remaining: 27.4ms
# 195:	learn: 2303.0360153	total: 1.07s	remaining: 21.9ms
# 196:	learn: 2302.4760148	total: 1.08s	remaining: 16.4ms
# 197:	learn: 2301.7862795	total: 1.08s	remaining: 10.9ms
# 198:	learn: 2301.3442648	total: 1.09s	remaining: 5.46ms
# 199:	learn: 2300.9555813	total: 1.09s	remaining: 0us
# Training on CPU
# Estimator 0/100, Train metric: 4785.5781
# Estimator 1/100, Train metric: 4716.0503
# Estimator 2/100, Train metric: 4644.9238
# Estimator 3/100, Train metric: 4567.3071
# Estimator 4/100, Train metric: 4485.7036
# Estimator 5/100, Train metric: 4414.1963
# Estimator 6/100, Train metric: 4342.2041
# Estimator 7/100, Train metric: 4294.3203
# Estimator 8/100, Train metric: 4232.3247
# Estimator 9/100, Train metric: 4175.2485
# Estimator 10/100, Train metric: 4117.8438
# Estimator 11/100, Train metric: 4074.5427
# Estimator 12/100, Train metric: 4027.6052
# Estimator 13/100, Train metric: 3969.5894
# Estimator 14/100, Train metric: 3934.0879
# Estimator 15/100, Train metric: 3884.0276
# Estimator 16/100, Train metric: 3849.3979
# Estimator 17/100, Train metric: 3796.5886
# Estimator 18/100, Train metric: 3756.7878
# Estimator 19/100, Train metric: 3707.1123
# Estimator 20/100, Train metric: 3662.5784
# Estimator 21/100, Train metric: 3627.9343
# Estimator 22/100, Train metric: 3589.0693
# Estimator 23/100, Train metric: 3559.3635
# Estimator 24/100, Train metric: 3519.8503
# Estimator 25/100, Train metric: 3486.7107
# Estimator 26/100, Train metric: 3455.1050
# Estimator 27/100, Train metric: 3425.0452
# Estimator 28/100, Train metric: 3410.2742
# Estimator 29/100, Train metric: 3380.3259
# Estimator 30/100, Train metric: 3368.2126
# Estimator 31/100, Train metric: 3338.4089
# Estimator 32/100, Train metric: 3314.2478
# Estimator 33/100, Train metric: 3298.9172
# Estimator 34/100, Train metric: 3274.0374
# Estimator 35/100, Train metric: 3259.7502
# Estimator 36/100, Train metric: 3242.4282
# Estimator 37/100, Train metric: 3222.9932
# Estimator 38/100, Train metric: 3209.1711
# Estimator 39/100, Train metric: 3196.1951
# Estimator 40/100, Train metric: 3181.8035
# Estimator 41/100, Train metric: 3170.4497
# Estimator 42/100, Train metric: 3156.1653
# Estimator 43/100, Train metric: 3139.1514
# Estimator 44/100, Train metric: 3124.4719
# Estimator 45/100, Train metric: 3112.9504
# Estimator 46/100, Train metric: 3102.4482
# Estimator 47/100, Train metric: 3091.2197
# Estimator 48/100, Train metric: 3077.9343
# Estimator 49/100, Train metric: 3065.4868
# Estimator 50/100, Train metric: 3069.4087
# Estimator 51/100, Train metric: 3057.7764
# Estimator 52/100, Train metric: 3047.5630
# Estimator 53/100, Train metric: 3035.9792
# Estimator 54/100, Train metric: 3026.7917
# Estimator 55/100, Train metric: 3020.9639
# Estimator 56/100, Train metric: 3010.0757
# Estimator 57/100, Train metric: 3005.9148
# Estimator 58/100, Train metric: 3001.2415
# Estimator 59/100, Train metric: 2995.9473
# Estimator 60/100, Train metric: 2985.3713
# Estimator 61/100, Train metric: 2980.9819
# Estimator 62/100, Train metric: 2975.9624
# Estimator 63/100, Train metric: 2971.2502
# Estimator 64/100, Train metric: 2966.4805
# Estimator 65/100, Train metric: 2960.4290
# Estimator 66/100, Train metric: 2957.1323
# Estimator 67/100, Train metric: 2950.0166
# Estimator 68/100, Train metric: 2945.8262
# Estimator 69/100, Train metric: 2941.5364
# Estimator 70/100, Train metric: 2939.0271
# Estimator 71/100, Train metric: 2934.4133
# Estimator 72/100, Train metric: 2930.0994
# Estimator 73/100, Train metric: 2926.9014
# Estimator 74/100, Train metric: 2922.0410
# Estimator 75/100, Train metric: 2919.2212
# Estimator 76/100, Train metric: 2915.2844
# Estimator 77/100, Train metric: 2913.6797
# Estimator 78/100, Train metric: 2912.4202
# Estimator 79/100, Train metric: 2908.8772
# Estimator 80/100, Train metric: 2904.2393
# Estimator 81/100, Train metric: 2900.8198
# Estimator 82/100, Train metric: 2898.2141
# Estimator 83/100, Train metric: 2896.2488
# Estimator 84/100, Train metric: 2894.7161
# Estimator 85/100, Train metric: 2891.2788
# Estimator 86/100, Train metric: 2889.5957
# Estimator 87/100, Train metric: 2888.5396
# Estimator 88/100, Train metric: 2885.8940
# Estimator 89/100, Train metric: 2882.8940
# Estimator 90/100, Train metric: 2881.8862
# Estimator 91/100, Train metric: 2878.5588
# Estimator 92/100, Train metric: 2875.9741
# Estimator 93/100, Train metric: 2872.4604
# Estimator 94/100, Train metric: 2870.9814
# Estimator 95/100, Train metric: 2870.4788
# Estimator 96/100, Train metric: 2871.1038
# Estimator 97/100, Train metric: 2867.2288
# Estimator 98/100, Train metric: 2864.3069
# Estimator 99/100, Train metric: 2864.2512

# %%
plot_best_scores(best_scores_autosampler,"./drive/MyDrive/Data_folder/HyperParameter_Tuning/test_results.xlsx")

# %%
generate_interpretml_explanations_summary_pruners(best_scores_autosampler, X_train, y_train, x_test, feature_names,excel_file_path = "./drive/MyDrive/Data_folder/HyperParameter_Tuning/test_results.xlsx")
# Out:
# WARNING:shap:Using 1095 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/365 [00:00<?, ?it/s]
# WARNING:shap:Using 1095 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/365 [00:00<?, ?it/s]
# WARNING:shap:Using 1095 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/365 [00:00<?, ?it/s]
# WARNING:shap:Using 1095 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/365 [00:00<?, ?it/s]
# WARNING:shap:Using 1095 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/365 [00:00<?, ?it/s]
# WARNING:shap:Using 1095 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/365 [00:00<?, ?it/s]
# WARNING:shap:Using 1095 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/365 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-246616322.py in <cell line: 0>()
# ----> 1 generate_interpretml_explanations_summary_pruners(best_scores_autosampler, X_train, y_train, x_test, feature_names,excel_file_path = "./drive/MyDrive/Data_folder/HyperParameter_Tuning/test_results.xlsx")
#
# /tmp/ipython-input-986475821.py in generate_interpretml_explanations_summary_pruners(results_dict, X_train, y_train, X_test, feature_names, instance_indices, excel_file_path)
#      59
#      60         model = model_class(**best_params)
# ---> 61         model.fit(X_train, y_train)
#      62
#      63         def predict_fn(data):
#
# /usr/local/lib/python3.12/dist-packages/pytorch_tabnet/tab_models/abstract_models/supervised_model.py in fit(self, X_train, y_train, eval_set, eval_name, eval_metric, loss_fn, weights, max_epochs, patience, batch_size, virtual_batch_size, num_workers, drop_last, callbacks, pin_memory, from_unsupervised, warm_start, compute_importance, *args, **kwargs)
#     110         check_array(X_train)
#     111
# --> 112         self.update_fit_params(
#     113             X_train,
#     114             y_train,
#
# /usr/local/lib/python3.12/dist-packages/pytorch_tabnet/tab_models/tab_reg.py in update_fit_params(self, X_train, y_train, eval_set, weights)
#     110                 + "Use reshape(-1, 1) for single regression."
#     111             )
# --> 112             raise ValueError(msg)
#     113         self.output_dim: int = y_train.shape[1]
#     114         self.preds_mapper: None = None
#
# ValueError: Targets should be 2D : (n_samples, n_regression) but y_train.shape=(1095,) given.
# Use reshape(-1, 1) for single regression.
